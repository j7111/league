# %% [markdown]
# # A League of Legends Recommender System

# %% [markdown]
# ## Part 1: Data Scraping & Cleaning

# %% [markdown]
# In this notebook we'll be collecting the necessary data to train our model off the [Riot API](https://developer.riotgames.com/) and [op.gg](https://www.op.gg/) website. Note that if you wish to run this notebook for yourself, you'll have to input your own Riot Development API Key in a `.env` file in the same folder as this notebook.
#
# In order to obtain the details of each match, such as items, rune builds, etc. for our model, we will first have to scrape the encrypted summoner IDs of all of the players on the ranked ladder using the League-V4 API. We'll only consider Diamond ranked and higher players, as this comprises the top-most 4.5% of players. As there are over 50,000 such players, we'll also have to scrape significantly fewer, due to rate limits on the API.
#
# After, we'll call the Account-V1 API to convert the encrypted summoner IDs to account PUUIDS. Then we use the Match-V5 API to retrieve the 10 most recently played ranked matches for each account. This should land us with a couple tens of thousands of matches ranked Emerald+, which will then need to be cleaned in the next notebook.

# %% [markdown]
# ---

# %% [markdown]
# Start by loading the API key in the `.env` file. If you create your own, it should be of the form
# ```
# api_key = '{YOUR_API_KEY}'
# ```
# Personal API keys are limited to
# - 20 requests every 1 second
# - 100 requests every 2 minutes

# %%
from dotenv import load_dotenv
import json
import os
import pandas as pd
import requests
import time
load_dotenv()
pd.set_option('display.max_columns', None)

# %%
# You will have to input your api key within your own .env file
api_key = os.environ.get('api_key')

# %% [markdown]
# We'll use the `requests` library to make calls to the API. To start off, we create a function that scrapes the ladder.

# %%
def get_ranked_players(tier, region='NA1', div_start=1, div_end=4, page_start=1, page_end=1):
    """
    Gets the encrypted summoner IDs of current ranked players of a single tier, all divisions.

    Args:
        tier (str): Tier of rankings to retrieve. Valid options are:
            - `CHALLENGER`
            - `GRANDMASTER`
            - `MASTER`
            - `DIAMOND`
            - `EMERALD`
            - `PLATINUM`
            - `GOLD`
            - `SILVER`
            - `BRONZE`
            - `IRON`
        region (str, optional): Region. Defaults to 'NA1'.
        div_start (int, optional): Only relevant for tiers `DIAMOND` and lower. Division to start retrieving on. Defaults to 1.
        div_end (int, optional): Only relevant for tiers `DIAMOND` and lower. Division to end retrieving on. Must be greater than or equal to div_start. Max of 4. Defaults to 4.
        page_start (int, optional): Only relevant for tiers `DIAMOND` and lower. Page to start retrieving on. Defaults to 1.
        page_end (int, optional): Only relevant for tiers `DIAMOND` and lower. Page to end retrieving on. Must be greater than or equal to page_start. Defaults to 1.

    Returns:
        list: Encrypted summoner IDs.

    Raises:
        ValueError: If `tier` is not valid.
        ValueError: If `div_end` is less than `div_start` or greater than 4.
        ValueError: If `page_end` is less than `page_start`.
        requests.exceptions.HTTPError: If an HTTP error occurs during the request.
        Exception: For other errors during the request.
    """

    # Validate tier
    valid_tiers = ['challenger', 'grandmaster', 'master', 'diamond', 'emerald', 'platinum', 'gold', 'silver', 'bronze', 'iron']
    if tier.lower() not in valid_tiers:
        raise ValueError('Invalid tier.')

    # Handle top 3 tiers with different URL
    if tier.lower() in ['challenger', 'grandmaster', 'master']:
        url = f'https://{region}.api.riotgames.com/lol/league/v4/{tier.lower()}leagues/by-queue/RANKED_SOLO_5x5?api_key={api_key}'
        try:
            print(f'Retrieving {tier.capitalize()}')
            response = requests.get(url)
            response.raise_for_status()             # Check if the request was successful
            return [entry['summonerId'] for entry in response.json()['entries']]

        except requests.exceptions.HTTPError as http_err:
            print(f'HTTP error occurred: {http_err}')
            raise
        except Exception as err:
            print(f'Error occurred: {err}')
            raise

    # Validate divisions and pages
    if div_start > div_end or div_end > 4:
        raise ValueError('div_end must be greater than or equal to div_start and less than or equal to 4.')
    if page_start > page_end or page_start < 1:
        raise ValueError('page_start must be greater than 0 and less than or equal to page_end.')

    summoner_ids = []
    divisions = ['I', 'II', 'III', 'IV'][div_start - 1:div_end]

    # Loop through selected divisions
    for div in divisions:
        # Loop through selected pages
        for page in range(page_start, page_end + 1):
            url = f'https://{region}.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{tier.upper()}/{div}?page={page}&api_key={api_key}'
            try:
                print(f'Retrieving {tier.capitalize()} {div} page {page}')
                api_response = requests.get(url)
                api_response.raise_for_status()     # Check if the request was successful
                data = api_response.json()
                summoner_ids.extend(entry['summonerId'] for entry in data)
                
                # To avoid hitting API limits. Do not run on final loop
                if not (div == divisions[-1] and page == page_end):
                    time.sleep(1.25)

            except requests.exceptions.HTTPError as http_err:
                print(f'HTTP error occurred: {http_err}')
                raise
            except Exception as err:
                print(f'Error occurred: {err}')
                raise

    return summoner_ids

# %%
challenger_players = get_ranked_players(tier='challenger')
time.sleep(1.25)
grandmaster_players = get_ranked_players(tier='grandmaster')
time.sleep(1.25)
master_players = get_ranked_players(tier='master')
time.sleep(1.25)
# Out:
# Retrieving Challenger
# Retrieving Grandmaster
# Retrieving Master

# %% [markdown]
# As master tier is quite large with 7,000 or so players, we'll drop 7/8 of them. This is simply so that we don't need to spend days requesting match data from the API. Probability wise, most of them will still appear in the previous matches of the players we request anyway.
#
# We'll also cut the number of challenger and grandmaster players by 3/4.

# %%
challenger_players_cut = challenger_players[::2][::2]
grandmaster_players_cut = grandmaster_players[::2][::2]
master_players_cut = master_players[::2][::2][::2]

print(len(challenger_players_cut))
print(len(grandmaster_players_cut))
print(len(master_players_cut))
print(f'total: {len(challenger_players_cut + grandmaster_players_cut + master_players_cut)}')
# Out:
# 75
# 175
# 880
# total: 1130

# %% [markdown]
# For Diamond I, 5 pages are picked, again so as to limit the time needed due to API constraints. Pages are staggered to create better coverage of the division. We can use https://www.op.gg/statistics/tiers to see the number of players per division. Since each page in the API call contains 205 players, we can determine the total number of pages a division has and create an even spread from that. We will automate the scraping of the number of players per division via `Selenium`.
#
# **You will need to specify your own browser and webdriver paths in the codeblock below to run it.**

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

def scrape_opgg():
    # YOU WILL NEED TO SPECIFY YOUR OWN CHROME EXECUTABLE PATH
    chrome_options = Options()
    chrome_options.binary_location = r'YOUR\PATH\HERE'

    # WebDriver path
    chromedriver_path = os.path.join('utils', 'chromedriver-win64', 'chromedriver.exe')

    # Set up the WebDriver with automatic ChromeDriver management
    driver = webdriver.Chrome(service=Service(chromedriver_path), options=chrome_options)

    # Open the webpage
    driver.get("https://www.op.gg/statistics/tiers")

    # Wait for the table to load
    driver.implicitly_wait(2)

    # Find the table element
    table = driver.find_element(By.CSS_SELECTOR, "table")

    # Extract table rows
    rows = table.find_elements(By.TAG_NAME, "tr")

    # Loop through the rows and columns to get the data
    data = []
    for row in rows:
        cells = row.find_elements(By.TAG_NAME, "td")
        row_data = [cell.text for cell in cells]
        data.append(row_data)

    driver.quit()

    return data

# %%
data = scrape_opgg()

# %%
# Filter out the data that isn't Diamond I+
data_temp = []
for entry in data[4:5]:     # Replace with your own splice if you want tiers and divisions other than just Diamond I
    data_temp.append(entry[2])

data_filtered = []
for entry in data_temp:
    # Remove the percentage part and any extra spaces
    number_str = entry.split(' ')[0]
    # Remove commas and convert to integer
    number = int(number_str.replace(',', ''))
    data_filtered.append(number)

data_filtered
# Out:
# [5628]

# %%
# Create dictionary for the next code block
diamond_i_count = data_filtered[0]
#diamond_counts = {i + 1: data_filtered[i] for i in range(4)}
#emerald_counts = {i - 3: data_filtered[i] for i in range(4, 8)}

print(diamond_i_count)
#print(diamond_counts)
#print(emerald_counts)
# Out:
# 5628

# %% [markdown]
# Now we retrieve 5 pages from the Diamond I division. Because it would still be too time-consuming to request all of the matches from these players, we'll quarter it so that we have ~250 players.

# %%
diamond_i_players = []
#diamond_players = []
#emerald_players = []

for page in range(0, 5):
    page_start_end = max(1, diamond_i_count // 205 // 5 * page)     # (Page 1 and 1/5, 2/5, 3/5, 4/5 of diamond_i_count//205)
    diamond_i_players.extend(get_ranked_players(tier='diamond', div_start=1, div_end=1, page_start=page_start_end, page_end=page_start_end))
    time.sleep(1.25)

#for div in range(1, 5):
#    diamond_div_count = diamond_counts[div]
#    for page in range(0, 5):
#        page_start_end = max(1, diamond_div_count // 205 // 5 * page)     # (Page 1 and 1/5, 2/5, 3/5, 4/5 of diamond_div_count//205)
#        diamond_players.extend(get_ranked_players(tier='diamond', div_start=div, div_end=div, page_start=page_start_end, page_end=page_start_end))
#        time.sleep(1.25)

#for div in range(1, 5):
#    emerald_div_count = emerald_counts[div]
#    for page in range(0, 5):
#        page_start_end = max(1, emerald_div_count // 205 // 5 * page)
#        emerald_players.extend(get_ranked_players(tier='emerald', div_start=div, div_end=div, page_start=page_start_end, page_end=page_start_end))
#        time.sleep(1.25)
# Out:
# Retrieving Diamond I page 1
# Retrieving Diamond I page 5
# Retrieving Diamond I page 10
# Retrieving Diamond I page 15
# Retrieving Diamond I page 20

# %%
# Cutting number of Diamond I players in half
diamond_i_players_cut = diamond_i_players[::2]
#diamond_players_cut = diamond_players[::2][::2]
#emerald_players_cut = emerald_players[::2][::2]

print(len(diamond_i_players_cut))
#print(len(diamond_players_cut))
#print(len(emerald_players_cut))
# Out:
# 513

# %% [markdown]
# Merge everything together into one list and save it to a `.txt` file.

# %%
print(len(challenger_players_cut))
print(len(grandmaster_players_cut))
print(len(master_players_cut))
print(len(diamond_i_players_cut))
#print(len(diamond_players_cut))
#print(len(emerald_players_cut))

top_players = challenger_players_cut + grandmaster_players_cut + master_players_cut + diamond_i_players_cut #+ diamond_players_cut + emerald_players_cut
len(top_players)
# Out:
# 75
# 175
# 880
# 513
# 1643

# %%
os.makedirs('data', exist_ok=True)

with open(os.path.join('data', 'top_players.txt'), 'w') as file:
    for player in top_players:
        file.write(f'{player}\n')

del file, player

# %%
# Read top_players out of the .txt file in case no longer in memory
with open(os.path.join('data', 'top_players.txt'), 'r') as file:
    lines = file.readlines()

top_players = [line.strip() for line in lines]
del file, lines

# %% [markdown]
# Now we create the function to retrieve the account PUUID from the encrypted summoner ID.

# %%
def get_puuid(summonerId, region='NA1'):
    """
    Gets the PUUID from an encrypted summoner ID.

    Args:
        summonerId (str): Encrypted Summoner ID.
        region (str, optional): Region. Defaults to 'NA1'.

    Returns:
        str: puuid

    Raises:
        ValueError: If the summonerId is None.
        requests.exceptions.HTTPError: If an HTTP error occurs during the request.
        Exception: For other errors during the request.
    """

    if summonerId is None:
        raise ValueError('Empty summoner ID.')

    url = f'https://{region}.api.riotgames.com/lol/summoner/v4/summoners/{summonerId}?api_key={api_key}'
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()['puuid']

    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
        raise
    except Exception as err:
        print(f'Error occurred: {err}')
        raise

# %%
puuids = []
num_players = len(top_players)
for i, player in enumerate(top_players):
    print(f'Retrieving PUUID {i + 1} of {num_players}.')
    puuids.append(get_puuid(player))
    time.sleep(1.25)
# Out:
# Retrieving PUUID 1 of 1643.
# Retrieving PUUID 2 of 1643.
# Retrieving PUUID 3 of 1643.
# Retrieving PUUID 4 of 1643.
# Retrieving PUUID 5 of 1643.
# Retrieving PUUID 6 of 1643.
# Retrieving PUUID 7 of 1643.
# Retrieving PUUID 8 of 1643.
# Retrieving PUUID 9 of 1643.
# Retrieving PUUID 10 of 1643.
# Retrieving PUUID 11 of 1643.
# Retrieving PUUID 12 of 1643.
# Retrieving PUUID 13 of 1643.
# Retrieving PUUID 14 of 1643.
# Retrieving PUUID 15 of 1643.
# Retrieving PUUID 16 of 1643.
# Retrieving PUUID 17 of 1643.
# Retrieving PUUID 18 of 1643.
# Retrieving PUUID 19 of 1643.
# Retrieving PUUID 20 of 1643.
# Retrieving PUUID 21 of 1643.
# Retrieving PUUID 22 of 1643.
# Retrieving PUUID 23 of 1643.
# Retrieving PUUID 24 of 1643.
# Retrieving PUUID 25 of 1643.
# Retrieving PUUID 26 of 1643.
# Retrieving PUUID 27 of 1643.
# Retrieving PUUID 28 of 1643.
# Retrieving PUUID 29 of 1643.
# Retrieving PUUID 30 of 1643.
# Retrieving PUUID 31 of 1643.
# Retrieving PUUID 32 of 1643.
# Retrieving PUUID 33 of 1643.
# Retrieving PUUID 34 of 1643.
# Retrieving PUUID 35 of 1643.
# Retrieving PUUID 36 of 1643.
# Retrieving PUUID 37 of 1643.
# Retrieving PUUID 38 of 1643.
# Retrieving PUUID 39 of 1643.
# Retrieving PUUID 40 of 1643.
# Retrieving PUUID 41 of 1643.
# Retrieving PUUID 42 of 1643.
# Retrieving PUUID 43 of 1643.
# Retrieving PUUID 44 of 1643.
# Retrieving PUUID 45 of 1643.
# Retrieving PUUID 46 of 1643.
# Retrieving PUUID 47 of 1643.
# Retrieving PUUID 1637 of 1643.
# Retrieving PUUID 1638 of 1643.
# Retrieving PUUID 1639 of 1643.
# Retrieving PUUID 1640 of 1643.
# Retrieving PUUID 1641 of 1643.
# Retrieving PUUID 1642 of 1643.
# Retrieving PUUID 1643 of 1643.

# %%
os.makedirs('data', exist_ok=True)

with open(os.path.join('data', 'puuids.txt'), 'w') as file:
    for puuid in puuids:
        file.write(f'{puuid}\n')

del file, puuid

# %%
# Read puuids out of the .txt file in case no longer in memory
with open(os.path.join('data', 'puuids.txt'), 'r') as file:
    lines = file.readlines()

puuids = [line.strip() for line in lines]
del file, lines

# %% [markdown]
# Creating the function to retrieve the last few number of games played by a given PUUID.

# %%
def get_match_history(puuid, region='americas', start=0, count=20):
    """
    Gets the match history of player from their PUUID.

    Args:
        puuid (str): PUUID of player.
        region (str, optional): Region. Defaults to 'americas'.
        start (int, optional): Start index of matches. Defaults to 0
        count (int, optional): Number of match IDs to return. Max 100. Defaults to 20.

    Returns:
        list: match IDs.

    Raises:
        ValueError: If the puuid is None.
        requests.exceptions.HTTPError: If an HTTP error occurs during the request.
        Exception: For other errors during the request.
    """

    if puuid is None:
        raise ValueError('Empty PUUID.')

    url = f'https://{region}.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start={start}&count={count}&api_key={api_key}'
    try:
        print(f'Retrieving last {count} matches for {puuid}')
        response = requests.get(url)
        response.raise_for_status()
        return response.json()

    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
        raise
    except Exception as err:
        print(f'Error occurred: {err}')
        raise

# %%
matches = []

for i, puuid in enumerate(puuids):
    print(f'{i + 1} of {num_players}: ')
    matches.extend(get_match_history(puuid, count=5))       # Restrict to 5 games to save time querying the API
    time.sleep(1.25)
# Out:
# 1 of 1643:
# Retrieving last 5 matches for Wy78TgnLmlcE9ORqWb1FF16XT_FJA5rx-UhjdWcKc-_fektTs3-utiTLLUYe_e-VEIFYXxm5cX56XA
# 2 of 1643:
# Retrieving last 5 matches for MN8tavlvwHP2MIjVATHRVPmoVXFSzEUC-wmBeYZh_MXWgDNr9H6Xl6pv-5JcXMtcBlbq6uMU57SqBA
# 3 of 1643:
# Retrieving last 5 matches for -5FeHlelVSUfKPm8yG9yZRfe25Mj4AOz-i1GcPQZ8Bd8OoHbOB9Pg8eV5zQx0PxKXACTVlmfeDHVzg
# 4 of 1643:
# Retrieving last 5 matches for ka3y_RQrNPrq0wg75Z2yHEvsRtVhdK8RQfEthg02J4iWUBWJZbj5yLjPm3HoJpcQH3PMh6uIa7ktgw
# 5 of 1643:
# Retrieving last 5 matches for xypYuWILvH6MKgyYfEkDNZgb5Vs4WKrKNjZYwYUN71dvfpaxBZ6PEO6GehHYIUFtUNuLEcVQNeAR_Q
# 6 of 1643:
# Retrieving last 5 matches for 8qfeh7Q2eHiyNAvFAGrtrslkaT8oKgwC8roiZtqSZi61dclUFH6npnzMu7LQcAUxaMi36RxUqE6quQ
# 7 of 1643:
# Retrieving last 5 matches for 08_3fiFoVvu7LPx7qOFfiDVWZ1E6l7kSuxEKJTCORP_kyZm14uJtelEX_etbikKGNS30CtqU8FgzWA
# Retrieving last 5 matches for 87Ik8dPmUmVj5LuD_1TPJHrh2jlTy86jv_1H4Rd1KTrNvbMDmGF6MOWkkdwU91W4-jALxA-2OBkO8w
# 1630 of 1643:
# Retrieving last 5 matches for uJD-BZrUV0k6247XLxT2j8zmg5BahtdHu9TguhW69ig2ZzcsP-pzR_SsbdPKnFgrfIQAqZWPAod5vw
# 1631 of 1643:
# Retrieving last 5 matches for BFXpevPz03J2ACTW-TCRX8RoT4t5CjC365Y2kJLu8q52qHR58bvYnB6bO-22OuGbSmf18DpdoZ82LQ
# 1632 of 1643:
# Retrieving last 5 matches for wZ_1G9z2DeGRoR711m7zdJBTniwkRdSVvBJIgESiGMduXduRqUf29VV_DvhFB0TgOpd3wwtNPWOkZQ
# 1633 of 1643:
# Retrieving last 5 matches for uUEhd9DV0ZgoNU_56HOMtL2D4ikgEFyIdrr1IK5L4XlMNqaFYQHgy_TFACO84VczqV_xy4TPVL0Piw
# 1634 of 1643:
# Retrieving last 5 matches for BqTjsHeXCaSn3z_FFWt56TKiUypHJE0MiJ_d-fB118bLSCxQ4VAQYFovOIWa-BTxV5q5zuNXuLF01Q
# 1635 of 1643:
# Retrieving last 5 matches for z3xUsP8pkPsTcTztaUCKWBbhqZBRc0de3Bm7A1fwTUl8WWy8qnLO-cVqj_I6EUikThOeUioKNR5DDg
# 1636 of 1643:
# Retrieving last 5 matches for M89nlZo7x-5szN9c7OX9TNv5r0H6qwELnzYFFhxgN0q9fKxK5DiwBz4qpPSFUBZNh05T0OpeujjnIw
# 1637 of 1643:
# Retrieving last 5 matches for QWe_QpVHCqLE4EdqLr3i7FSZ79qASkXw6seuDK05I24iDut2-kwT6ketgmz2xhgSEYNDdLMmSBNWqA
# 1638 of 1643:
# Retrieving last 5 matches for jv8W9hKfHpEWnOV-WvdEbK1Qn071WkNhBazGJX7BksmDrKXpGy5SKUor2VF6ObI2mao4KVRVV16g8g
# 1639 of 1643:
# Retrieving last 5 matches for t8wHETbODbcwwqz6Y-Hiolx_R7ljGzLd0oLc_9rQyqxBQMrW6iJHXA23FVLCwEFSrYV_LxahfXJnWg
# 1640 of 1643:
# Retrieving last 5 matches for k-yXIW6_Q2AbVhb3u_9fajxZYDLY_WvV8WlGsTqwMM7v9DqwOgfEIugtWpg8mLqsN7Ic0rG18SJz8A
# 1641 of 1643:
# Retrieving last 5 matches for LZMLnks-5UR84lwfoUCD6uQ-WA1kC0X25HyTB6Dq-0CxZy23SAPVQYZkes8oOCcazBzK0SpBpsHVCQ
# 1642 of 1643:
# Retrieving last 5 matches for yH4lh-e6SYAd1Av3MVSx7ZZMpVsBLy0oYl7MSZac5SE2jkQNQMvJrkH20Ub5GghSTRKDQreD2wVz_Q
# 1643 of 1643:
# Retrieving last 5 matches for XaqzhIzk7cAJAvWbHhSvTwETYEH5jBgc6Dt-pqWqk-Ad36plvuUedCOFwXnwd_ew7uHfHYeUTvJdpA

# %%
# Removing duplicate matches
matches = list(set(matches))
len(matches)
# Out:
# 7268

# %%
os.makedirs('data', exist_ok=True)

with open(os.path.join('data', 'matches.txt'), 'w') as file:
    for match in matches:
        file.write(f'{match}\n')

del file, match

# %%
# Read matches out of the .txt file in case no longer in memory
with open(os.path.join('data', 'matches.txt'), 'r') as file:
    lines = file.readlines()

matches = [line.strip() for line in lines]
del file, lines

# %% [markdown]
# We now have close to 10,000 games to examine. We'll need a function which requests the API for the details of each match.

# %%
def get_match_details(matchId, region='americas'):
    """
    Gets the relevent details of a match from its ID.

    Args:
        matchId (str): ID of the match.
        region (str, optional): Region. Defaults to 'americas'.

    Returns:
        dict: All of the match details.

    Raises:
        ValueError: If the matchId is None.
        requests.exceptions.HTTPError: If an HTTP error occurs during the request.
        Exception: For other errors during the request.
    """

    if matchId is None:
        raise ValueError('Empty matchId.')

    url = f'https://{region}.api.riotgames.com/lol/match/v5/matches/{matchId}?api_key={api_key}'
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()

    except requests.exceptions.HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
        raise
    except Exception as err:
        print(f'Error occurred: {err}')
        raise

# %% [markdown]
# Now we get the details of all of our matches.

# %%
matches_detailed = []
num_matches = len(matches)

for i, match in enumerate(matches):
    print(f'Retrieving details for match {i + 1} of {num_matches}.')
    matches_detailed.append(get_match_details(match))
    time.sleep(1.25)
# Out:
# Retrieving details for match 1 of 7268.
# Retrieving details for match 2 of 7268.
# Retrieving details for match 3 of 7268.
# Retrieving details for match 4 of 7268.
# Retrieving details for match 5 of 7268.
# Retrieving details for match 6 of 7268.
# Retrieving details for match 7 of 7268.
# Retrieving details for match 8 of 7268.
# Retrieving details for match 9 of 7268.
# Retrieving details for match 10 of 7268.
# Retrieving details for match 11 of 7268.
# Retrieving details for match 12 of 7268.
# Retrieving details for match 13 of 7268.
# Retrieving details for match 14 of 7268.
# Retrieving details for match 15 of 7268.
# Retrieving details for match 16 of 7268.
# Retrieving details for match 17 of 7268.
# Retrieving details for match 18 of 7268.
# Retrieving details for match 19 of 7268.
# Retrieving details for match 20 of 7268.
# Retrieving details for match 21 of 7268.
# Retrieving details for match 22 of 7268.
# Retrieving details for match 23 of 7268.
# Retrieving details for match 24 of 7268.
# Retrieving details for match 25 of 7268.
# Retrieving details for match 26 of 7268.
# Retrieving details for match 27 of 7268.
# Retrieving details for match 28 of 7268.
# Retrieving details for match 29 of 7268.
# Retrieving details for match 30 of 7268.
# Retrieving details for match 31 of 7268.
# Retrieving details for match 32 of 7268.
# Retrieving details for match 33 of 7268.
# Retrieving details for match 34 of 7268.
# Retrieving details for match 35 of 7268.
# Retrieving details for match 36 of 7268.
# Retrieving details for match 37 of 7268.
# Retrieving details for match 38 of 7268.
# Retrieving details for match 39 of 7268.
# Retrieving details for match 40 of 7268.
# Retrieving details for match 41 of 7268.
# Retrieving details for match 42 of 7268.
# Retrieving details for match 43 of 7268.
# Retrieving details for match 44 of 7268.
# Retrieving details for match 45 of 7268.
# Retrieving details for match 46 of 7268.
# Retrieving details for match 47 of 7268.
# Retrieving details for match 48 of 7268.
# Retrieving details for match 49 of 7268.
# Retrieving details for match 50 of 7268.
# Retrieving details for match 51 of 7268.
# Retrieving details for match 52 of 7268.
# Retrieving details for match 53 of 7268.
# Retrieving details for match 54 of 7268.
# Retrieving details for match 7237 of 7268.
# Retrieving details for match 7238 of 7268.
# Retrieving details for match 7239 of 7268.
# Retrieving details for match 7240 of 7268.
# Retrieving details for match 7241 of 7268.
# Retrieving details for match 7242 of 7268.
# Retrieving details for match 7243 of 7268.
# Retrieving details for match 7244 of 7268.
# Retrieving details for match 7245 of 7268.
# Retrieving details for match 7246 of 7268.
# Retrieving details for match 7247 of 7268.
# Retrieving details for match 7248 of 7268.
# Retrieving details for match 7249 of 7268.
# Retrieving details for match 7250 of 7268.
# Retrieving details for match 7251 of 7268.
# Retrieving details for match 7252 of 7268.
# Retrieving details for match 7253 of 7268.
# Retrieving details for match 7254 of 7268.
# Retrieving details for match 7255 of 7268.
# Retrieving details for match 7256 of 7268.
# Retrieving details for match 7257 of 7268.
# Retrieving details for match 7258 of 7268.
# Retrieving details for match 7259 of 7268.
# Retrieving details for match 7260 of 7268.
# Retrieving details for match 7261 of 7268.
# Retrieving details for match 7262 of 7268.
# Retrieving details for match 7263 of 7268.
# Retrieving details for match 7264 of 7268.
# Retrieving details for match 7265 of 7268.
# Retrieving details for match 7266 of 7268.
# Retrieving details for match 7267 of 7268.
# Retrieving details for match 7268 of 7268.

# %% [markdown]
# As this particular step will take a very long time without a developer API key, we may need to stop and continue the process for various reasons, such as the Riot API crashing (as it sometimes does) or needing to refresh the API key. It also seems like some matches may end up being purged from the server.

# %%
for i in range(--, num_matches):
    print(f'Retrieving details for match {i + 1} of {num_matches}.')
    matches_detailed.append(get_match_details(matches[i]))
    time.sleep(1.25)

# %%
len(matches_detailed)
# Out:
# 7268

# %%
os.makedirs('data', exist_ok=True)

with open(os.path.join('data', 'matches_detailed.txt'), 'w') as file:
    json.dump(matches_detailed, file, indent=1)

# %%
# Read match details out of the .txt file in case no longer in memory
with open(os.path.join('data', 'matches_detailed.txt'), 'r') as file:
    matches_detailed = json.load(file)

del file

# %% [markdown]
# As the file storing the data is now well over 700MB in size, it will not be included in the GitHub repository. We should now have approximately 5,000 - 6,000 or so games (after removing non-ranked matches) worth of data. Unfortunately, this is not even close to the amount of data we could have should we get every match from every Diamond I+ player, but it would simply be too time-consuming and memory-heavy to include them. We could process it in batches to circumvent this, but we choose not to do that for this particular project.
#
# The details of each match are contained in JSON format, so we'll need to extract out the information. While there exists a ton of information in the match details, we'll only take the information that we find most relevant with regards to performing some exploratory data analysis in the next part. We'll also drop the games that are either not ranked games, are remakes (game lasts less than 15 minutes), or are bot games (which for some reason are classified as ranked).

# %%
# Recursively search through JSON to extract values associated with a key
def json_extract(obj, key):
    def extract(obj, key):
        values = []
        if isinstance(obj, dict):
            for k, v in obj.items():
                if k == key:
                    values.append(v)
                if isinstance(v, (dict, list)):
                    values.extend(extract(v, key))
        elif isinstance(obj, list):
            for item in obj:
                values.extend(extract(item, key))

        return values

    return extract(obj, key)



def process_match(match_json):
    """
    Processes the match via its JSON into a pandas DataFrame with the most relevant information.

    Args:
        match_json (dict): The JSON of match details.

    Returns:
        pd.DataFrame: A Dataframe containing the relevant match information.

    Raises:
        ValueError: If the match is not a ranked game or the game duration is less than 15 minutes.
    """

    info = match_json['info']
    players = info['participants']

    # Filter out non-ranked games and remakes
    if info['queueId'] != 420:
        raise ValueError('Not a ranked game.')
    if info['gameDuration'] < 900:
        raise ValueError('Game too short.')

    # Define columns of DataFrame
    match_data = {
        'Match ID': [match_json['metadata']['matchId']] * 10,
        'Game Duration': [info['gameDuration']] * 10,
        'Game Version': [info['gameVersion']] * 10,
        'Summoner Name': [player['riotIdGameName'] if 'riotIdGameName' in player else player['riotIdName'] for player in players],
        'Summoner Tag': [player['riotIdTagline'] for player in players],
        'Champion ID': [player['championId'] for player in players],
        'Champion Name': [player['championName'] for player in players],
        'Champion Level': [player['champLevel'] for player in players],
        'Team': [player['teamId'] for player in players],
        'Role': [player['teamPosition'] for player in players],
        'Kills': [player['kills'] for player in players],
        'Deaths': [player['challenges']['deathsByEnemyChamps'] for player in players],
        'Assists': [player['assists'] for player in players],
        'CS': [player['totalMinionsKilled']for player in players],
        'CS (Jungle)': [(player['totalAllyJungleMinionsKilled'] + player['totalEnemyJungleMinionsKilled']) for player in players],
        'First Blood': [player['firstBloodKill'] for player in players],
        'First Tower': [player['firstTowerKill'] for player in players],
        'Objective Stolen': [player['objectivesStolen'] for player in players],
        'Total Gold Earned': [player['goldEarned'] for player in players],
        'Gold Spent': [player['goldSpent'] for player in players],
        'Gold/Minute': [player['challenges']['goldPerMinute'] for player in players],
        'Damage Dealt': [player['totalDamageDealtToChampions'] for player in players],
        '% of Team\'s Damage': [player['challenges']['teamDamagePercentage'] for player in players],
        'Damage Taken': [player['totalDamageTaken'] for player in players],
        'Damage Mitigated': [player['damageSelfMitigated'] for player in players],
        'Heal and Shielding': [player['challenges']['effectiveHealAndShielding'] for player in players],
        'CC Time Dealt': [player['totalTimeCCDealt'] for player in players],
        'Turret Plates Taken': [player['challenges']['turretPlatesTaken'] for player in players],
        'Turret Takedowns': [player['turretTakedowns'] for player in players],
        'Vision Score': [player['visionScore'] for player in players],
        'Rune 1': [player['perks']['styles'][0]['selections'][0]['perk'] for player in players],
        'Rune 2': [player['perks']['styles'][0]['selections'][1]['perk'] for player in players],
        'Rune 3': [player['perks']['styles'][0]['selections'][2]['perk'] for player in players],
        'Rune 4': [player['perks']['styles'][0]['selections'][3]['perk'] for player in players],
        'Sec Rune 1': [player['perks']['styles'][1]['selections'][0]['perk'] for player in players],
        'Sec Rune 2': [player['perks']['styles'][1]['selections'][1]['perk'] for player in players],
        'Stat 1': [player['perks']['statPerks']['offense'] for player in players],
        'Stat 2': [player['perks']['statPerks']['flex'] for player in players],
        'Stat 3': [player['perks']['statPerks']['defense'] for player in players],
        'Summ 1': [player['summoner1Id'] for player in players],
        'Summ 2': [player['summoner2Id'] for player in players],
        'Item 1': [player['item0'] for player in players],
        'Item 2': [player['item1'] for player in players],
        'Item 3': [player['item2'] for player in players],
        'Item 4': [player['item3'] for player in players],
        'Item 5': [player['item4'] for player in players],
        'Item 6': [player['item5'] for player in players],
        #'Ward': [player['item6'] for player in players],
        'Triplekills': [player['tripleKills'] for player in players],
        'Quadrakills': [player['quadraKills'] for player in players],
        'Pentakills': [player['pentaKills'] for player in players],
        'Grubs Taken (Team)': [info['teams'][0]['objectives']['horde']['kills'] if player['teamId'] == 100
                          else info['teams'][1]['objectives']['horde']['kills'] for player in players],
        'Heralds Taken (Team)': [info['teams'][0]['objectives']['riftHerald']['kills'] if player['teamId'] == 100
                            else info['teams'][1]['objectives']['riftHerald']['kills'] for player in players],
        'Barons Taken (Team)': [info['teams'][0]['objectives']['baron']['kills'] if player['teamId'] == 100
                           else info['teams'][1]['objectives']['baron']['kills'] for player in players],
        'Dragons Taken (Team)': [info['teams'][0]['objectives']['dragon']['kills'] if player['teamId'] == 100
                            else info['teams'][1]['objectives']['dragon']['kills'] for player in players],
        'Game Ended in Surrender': [player['gameEndedInSurrender'] for player in players],
        'Win': [player['win'] for player in players]
    }

    match_df = pd.DataFrame(match_data)

    return match_df

# %%
all_matches_df = pd.DataFrame()
num_matches_detailed = len(matches_detailed)

for i, match in enumerate(matches_detailed):
    try:
        print(f'Processing match {i + 1} of {num_matches_detailed}.')
        match_df = process_match(match)
        # Append latest match to the cumulative DataFrame
        all_matches_df = pd.concat([all_matches_df, match_df], ignore_index=True)
    except ValueError as e:
        print(f'Error processing match {i + 1}: {e} Skipping this match.')
# Out:
# Processing match 1 of 7268.
# Processing match 2 of 7268.
# Processing match 3 of 7268.
# Error processing match 3: Not a ranked game. Skipping this match.
# Processing match 4 of 7268.
# Processing match 5 of 7268.
# Processing match 6 of 7268.
# Processing match 7 of 7268.
# Processing match 8 of 7268.
# Error processing match 8: Not a ranked game. Skipping this match.
# Processing match 9 of 7268.
# Processing match 10 of 7268.
# Error processing match 10: Not a ranked game. Skipping this match.
# Processing match 11 of 7268.
# Processing match 12 of 7268.
# Processing match 13 of 7268.
# Processing match 14 of 7268.
# Processing match 15 of 7268.
# Processing match 16 of 7268.
# Error processing match 16: Not a ranked game. Skipping this match.
# Processing match 17 of 7268.
# Error processing match 17: Not a ranked game. Skipping this match.
# Processing match 18 of 7268.
# Processing match 19 of 7268.
# Processing match 20 of 7268.
# Processing match 21 of 7268.
# Error processing match 21: Not a ranked game. Skipping this match.
# Processing match 22 of 7268.
# Processing match 23 of 7268.
# Processing match 24 of 7268.
# Processing match 25 of 7268.
# Error processing match 25: Not a ranked game. Skipping this match.
# Processing match 26 of 7268.
# Processing match 27 of 7268.
# Error processing match 27: Not a ranked game. Skipping this match.
# Processing match 28 of 7268.
# Error processing match 28: Not a ranked game. Skipping this match.
# Processing match 29 of 7268.
# Processing match 30 of 7268.
# Processing match 31 of 7268.
# Processing match 32 of 7268.
# Error processing match 32: Game too short. Skipping this match.
# Processing match 33 of 7268.
# Error processing match 33: Not a ranked game. Skipping this match.
# Processing match 34 of 7268.
# Error processing match 34: Not a ranked game. Skipping this match.
# Processing match 35 of 7268.
# Processing match 36 of 7268.
# Error processing match 36: Not a ranked game. Skipping this match.
# Processing match 37 of 7268.
# Error processing match 37: Not a ranked game. Skipping this match.
# Processing match 38 of 7268.
# Error processing match 38: Not a ranked game. Skipping this match.
# Processing match 39 of 7268.
# Error processing match 39: Not a ranked game. Skipping this match.
# Processing match 40 of 7268.
# Processing match 41 of 7268.
# Error processing match 41: Not a ranked game. Skipping this match.
# Processing match 42 of 7268.
# Processing match 43 of 7268.
# Error processing match 43: Not a ranked game. Skipping this match.
# Processing match 44 of 7268.
# Error processing match 44: Not a ranked game. Skipping this match.
# Processing match 45 of 7268.
# Processing match 46 of 7268.
# Processing match 47 of 7268.
# Error processing match 47: Not a ranked game. Skipping this match.
# Processing match 48 of 7268.
# Processing match 49 of 7268.
# Processing match 50 of 7268.
# Error processing match 50: Not a ranked game. Skipping this match.
# Processing match 51 of 7268.
# Error processing match 51: Not a ranked game. Skipping this match.
# Processing match 52 of 7268.
# Processing match 53 of 7268.
# Processing match 54 of 7268.
# Processing match 55 of 7268.
# Processing match 56 of 7268.
# Processing match 57 of 7268.
# Error processing match 57: Game too short. Skipping this match.
# Processing match 58 of 7268.
# Processing match 59 of 7268.
# Processing match 60 of 7268.
# Processing match 61 of 7268.
# Processing match 62 of 7268.
# Error processing match 62: Not a ranked game. Skipping this match.
# Processing match 63 of 7268.
# Processing match 64 of 7268.
# Processing match 65 of 7268.
# Processing match 66 of 7268.
# Error processing match 66: Not a ranked game. Skipping this match.
# Processing match 67 of 7268.
# Processing match 68 of 7268.
# Error processing match 68: Not a ranked game. Skipping this match.
# Processing match 69 of 7268.
# Processing match 70 of 7268.
# Error processing match 70: Not a ranked game. Skipping this match.
# Processing match 71 of 7268.
# Error processing match 71: Not a ranked game. Skipping this match.
# Processing match 72 of 7268.
# Error processing match 72: Not a ranked game. Skipping this match.
# Processing match 73 of 7268.
# Processing match 74 of 7268.
# Processing match 75 of 7268.
# Processing match 76 of 7268.
# Error processing match 76: Not a ranked game. Skipping this match.
# Processing match 77 of 7268.
# Error processing match 77: Game too short. Skipping this match.
# Processing match 78 of 7268.
# Processing match 79 of 7268.
# Error processing match 79: Not a ranked game. Skipping this match.
# Processing match 80 of 7268.
# Processing match 81 of 7268.
# Processing match 82 of 7268.
# Processing match 83 of 7268.
# Error processing match 83: Not a ranked game. Skipping this match.
# Processing match 84 of 7268.
# Error processing match 84: Not a ranked game. Skipping this match.
# Processing match 85 of 7268.
# Error processing match 85: Game too short. Skipping this match.
# Processing match 86 of 7268.
# Processing match 87 of 7268.
# Error processing match 87: Not a ranked game. Skipping this match.
# Processing match 88 of 7268.
# Processing match 89 of 7268.
# Processing match 90 of 7268.
# Processing match 91 of 7268.
# Error processing match 91: Not a ranked game. Skipping this match.
# Processing match 92 of 7268.
# Processing match 93 of 7268.
# Processing match 94 of 7268.
# Processing match 95 of 7268.
# Error processing match 95: Not a ranked game. Skipping this match.
# Processing match 96 of 7268.
# Error processing match 96: Game too short. Skipping this match.
# Processing match 97 of 7268.
# Processing match 98 of 7268.
# Processing match 99 of 7268.
# Processing match 100 of 7268.
# Error processing match 100: Not a ranked game. Skipping this match.
# Processing match 101 of 7268.
# Error processing match 101: Not a ranked game. Skipping this match.
# Processing match 102 of 7268.
# Processing match 103 of 7268.
# Error processing match 103: Not a ranked game. Skipping this match.
# Processing match 104 of 7268.
# Error processing match 104: Not a ranked game. Skipping this match.
# Processing match 105 of 7268.
# Processing match 106 of 7268.
# Processing match 107 of 7268.
# Processing match 108 of 7268.
# Error processing match 108: Not a ranked game. Skipping this match.
# Processing match 109 of 7268.
# Error processing match 109: Not a ranked game. Skipping this match.
# Processing match 110 of 7268.
# Processing match 111 of 7268.
# Processing match 112 of 7268.
# Error processing match 112: Not a ranked game. Skipping this match.
# Processing match 113 of 7268.
# Processing match 114 of 7268.
# Processing match 115 of 7268.
# Processing match 116 of 7268.
# Processing match 117 of 7268.
# Error processing match 117: Not a ranked game. Skipping this match.
# Processing match 118 of 7268.
# Error processing match 118: Not a ranked game. Skipping this match.
# Processing match 119 of 7268.
# Processing match 120 of 7268.
# Processing match 121 of 7268.
# Error processing match 121: Not a ranked game. Skipping this match.
# Processing match 122 of 7268.
# Processing match 123 of 7268.
# Error processing match 123: Not a ranked game. Skipping this match.
# Processing match 124 of 7268.
# Error processing match 124: Not a ranked game. Skipping this match.
# Processing match 125 of 7268.
# Error processing match 125: Not a ranked game. Skipping this match.
# Processing match 126 of 7268.
# Processing match 127 of 7268.
# Error processing match 127: Not a ranked game. Skipping this match.
# Processing match 128 of 7268.
# Processing match 129 of 7268.
# Processing match 130 of 7268.
# Processing match 131 of 7268.
# Processing match 132 of 7268.
# Processing match 133 of 7268.
# Processing match 134 of 7268.
# Error processing match 134: Not a ranked game. Skipping this match.
# Processing match 135 of 7268.
# Processing match 136 of 7268.
# Processing match 137 of 7268.
# Processing match 138 of 7268.
# Processing match 139 of 7268.
# Error processing match 139: Not a ranked game. Skipping this match.
# Processing match 140 of 7268.
# Processing match 141 of 7268.
# Processing match 142 of 7268.
# Processing match 143 of 7268.
# Error processing match 143: Not a ranked game. Skipping this match.
# Processing match 144 of 7268.
# Processing match 145 of 7268.
# Error processing match 145: Not a ranked game. Skipping this match.
# Processing match 146 of 7268.
# Processing match 147 of 7268.
# Error processing match 147: Not a ranked game. Skipping this match.
# Processing match 148 of 7268.
# Error processing match 148: Not a ranked game. Skipping this match.
# Processing match 149 of 7268.
# Processing match 150 of 7268.
# Processing match 151 of 7268.
# Processing match 152 of 7268.
# Processing match 153 of 7268.
# Processing match 154 of 7268.
# Processing match 155 of 7268.
# Processing match 156 of 7268.
# Processing match 157 of 7268.
# Processing match 158 of 7268.
# Error processing match 158: Not a ranked game. Skipping this match.
# Processing match 159 of 7268.
# Processing match 160 of 7268.
# Error processing match 160: Not a ranked game. Skipping this match.
# Processing match 161 of 7268.
# Error processing match 161: Not a ranked game. Skipping this match.
# Processing match 162 of 7268.
# Error processing match 162: Not a ranked game. Skipping this match.
# Processing match 163 of 7268.
# Processing match 164 of 7268.
# Processing match 165 of 7268.
# Error processing match 165: Not a ranked game. Skipping this match.
# Processing match 166 of 7268.
# Processing match 167 of 7268.
# Processing match 168 of 7268.
# Processing match 169 of 7268.
# Error processing match 169: Not a ranked game. Skipping this match.
# Processing match 170 of 7268.
# Processing match 171 of 7268.
# Error processing match 171: Not a ranked game. Skipping this match.
# Processing match 172 of 7268.
# Error processing match 172: Not a ranked game. Skipping this match.
# Processing match 173 of 7268.
# Error processing match 173: Not a ranked game. Skipping this match.
# Processing match 174 of 7268.
# Processing match 175 of 7268.
# Processing match 176 of 7268.
# Error processing match 176: Not a ranked game. Skipping this match.
# Processing match 177 of 7268.
# Error processing match 177: Not a ranked game. Skipping this match.
# Processing match 178 of 7268.
# Processing match 179 of 7268.
# Error processing match 179: Not a ranked game. Skipping this match.
# Processing match 180 of 7268.
# Error processing match 180: Not a ranked game. Skipping this match.
# Processing match 181 of 7268.
# Processing match 182 of 7268.
# Error processing match 182: Not a ranked game. Skipping this match.
# Processing match 183 of 7268.
# Processing match 184 of 7268.
# Processing match 185 of 7268.
# Processing match 186 of 7268.
# Error processing match 186: Not a ranked game. Skipping this match.
# Processing match 187 of 7268.
# Error processing match 187: Not a ranked game. Skipping this match.
# Processing match 188 of 7268.
# Processing match 189 of 7268.
# Processing match 190 of 7268.
# Error processing match 190: Not a ranked game. Skipping this match.
# Processing match 191 of 7268.
# Processing match 192 of 7268.
# Processing match 193 of 7268.
# Error processing match 193: Not a ranked game. Skipping this match.
# Processing match 194 of 7268.
# Error processing match 194: Not a ranked game. Skipping this match.
# Processing match 195 of 7268.
# Error processing match 195: Not a ranked game. Skipping this match.
# Processing match 196 of 7268.
# Processing match 197 of 7268.
# Processing match 198 of 7268.
# Processing match 199 of 7268.
# Error processing match 199: Not a ranked game. Skipping this match.
# Processing match 200 of 7268.
# Processing match 201 of 7268.
# Processing match 202 of 7268.
# Processing match 203 of 7268.
# Processing match 204 of 7268.
# Processing match 205 of 7268.
# Error processing match 205: Not a ranked game. Skipping this match.
# Processing match 206 of 7268.
# Processing match 207 of 7268.
# Processing match 208 of 7268.
# Error processing match 208: Not a ranked game. Skipping this match.
# Processing match 209 of 7268.
# Processing match 210 of 7268.
# Processing match 211 of 7268.
# Error processing match 211: Game too short. Skipping this match.
# Processing match 212 of 7268.
# Processing match 213 of 7268.
# Error processing match 213: Not a ranked game. Skipping this match.
# Processing match 214 of 7268.
# Processing match 215 of 7268.
# Processing match 216 of 7268.
# Processing match 217 of 7268.
# Error processing match 217: Not a ranked game. Skipping this match.
# Processing match 218 of 7268.
# Processing match 219 of 7268.
# Processing match 220 of 7268.
# Processing match 221 of 7268.
# Processing match 222 of 7268.
# Processing match 223 of 7268.
# Error processing match 223: Not a ranked game. Skipping this match.
# Processing match 224 of 7268.
# Processing match 225 of 7268.
# Error processing match 225: Not a ranked game. Skipping this match.
# Processing match 226 of 7268.
# Processing match 227 of 7268.
# Error processing match 227: Not a ranked game. Skipping this match.
# Processing match 228 of 7268.
# Processing match 229 of 7268.
# Processing match 230 of 7268.
# Processing match 231 of 7268.
# Error processing match 231: Not a ranked game. Skipping this match.
# Processing match 232 of 7268.
# Processing match 233 of 7268.
# Processing match 234 of 7268.
# Processing match 235 of 7268.
# Processing match 236 of 7268.
# Processing match 237 of 7268.
# Processing match 238 of 7268.
# Processing match 239 of 7268.
# Processing match 240 of 7268.
# Error processing match 240: Not a ranked game. Skipping this match.
# Processing match 241 of 7268.
# Processing match 242 of 7268.
# Error processing match 242: Not a ranked game. Skipping this match.
# Processing match 243 of 7268.
# Processing match 244 of 7268.
# Error processing match 244: Not a ranked game. Skipping this match.
# Processing match 245 of 7268.
# Error processing match 245: Not a ranked game. Skipping this match.
# Processing match 246 of 7268.
# Error processing match 246: Not a ranked game. Skipping this match.
# Processing match 247 of 7268.
# Error processing match 247: Not a ranked game. Skipping this match.
# Processing match 248 of 7268.
# Processing match 249 of 7268.
# Processing match 250 of 7268.
# Processing match 251 of 7268.
# Processing match 252 of 7268.
# Error processing match 252: Not a ranked game. Skipping this match.
# Processing match 253 of 7268.
# Processing match 254 of 7268.
# Processing match 255 of 7268.
# Processing match 256 of 7268.
# Error processing match 256: Not a ranked game. Skipping this match.
# Processing match 257 of 7268.
# Error processing match 257: Not a ranked game. Skipping this match.
# Processing match 258 of 7268.
# Processing match 259 of 7268.
# Processing match 260 of 7268.
# Processing match 261 of 7268.
# Processing match 262 of 7268.
# Processing match 263 of 7268.
# Processing match 264 of 7268.
# Processing match 265 of 7268.
# Error processing match 265: Not a ranked game. Skipping this match.
# Processing match 266 of 7268.
# Processing match 267 of 7268.
# Processing match 268 of 7268.
# Processing match 269 of 7268.
# Processing match 270 of 7268.
# Processing match 271 of 7268.
# Processing match 272 of 7268.
# Error processing match 272: Not a ranked game. Skipping this match.
# Processing match 273 of 7268.
# Processing match 274 of 7268.
# Processing match 275 of 7268.
# Error processing match 275: Not a ranked game. Skipping this match.
# Processing match 276 of 7268.
# Error processing match 276: Not a ranked game. Skipping this match.
# Processing match 277 of 7268.
# Processing match 278 of 7268.
# Processing match 279 of 7268.
# Processing match 280 of 7268.
# Processing match 281 of 7268.
# Processing match 282 of 7268.
# Processing match 283 of 7268.
# Processing match 284 of 7268.
# Processing match 285 of 7268.
# Error processing match 285: Not a ranked game. Skipping this match.
# Processing match 286 of 7268.
# Processing match 287 of 7268.
# Error processing match 287: Not a ranked game. Skipping this match.
# Processing match 288 of 7268.
# Processing match 289 of 7268.
# Processing match 290 of 7268.
# Processing match 291 of 7268.
# Processing match 292 of 7268.
# Processing match 293 of 7268.
# Error processing match 293: Not a ranked game. Skipping this match.
# Processing match 294 of 7268.
# Error processing match 294: Not a ranked game. Skipping this match.
# Processing match 295 of 7268.
# Processing match 296 of 7268.
# Processing match 297 of 7268.
# Processing match 298 of 7268.
# Error processing match 298: Not a ranked game. Skipping this match.
# Processing match 299 of 7268.
# Processing match 300 of 7268.
# Error processing match 300: Not a ranked game. Skipping this match.
# Processing match 301 of 7268.
# Error processing match 301: Not a ranked game. Skipping this match.
# Processing match 302 of 7268.
# Processing match 303 of 7268.
# Error processing match 303: Not a ranked game. Skipping this match.
# Processing match 304 of 7268.
# Processing match 305 of 7268.
# Processing match 306 of 7268.
# Processing match 307 of 7268.
# Processing match 308 of 7268.
# Processing match 309 of 7268.
# Processing match 310 of 7268.
# Processing match 311 of 7268.
# Processing match 312 of 7268.
# Processing match 313 of 7268.
# Error processing match 313: Game too short. Skipping this match.
# Processing match 314 of 7268.
# Processing match 315 of 7268.
# Error processing match 315: Not a ranked game. Skipping this match.
# Processing match 316 of 7268.
# Processing match 317 of 7268.
# Processing match 318 of 7268.
# Processing match 319 of 7268.
# Error processing match 319: Not a ranked game. Skipping this match.
# Processing match 320 of 7268.
# Processing match 321 of 7268.
# Processing match 322 of 7268.
# Error processing match 322: Not a ranked game. Skipping this match.
# Processing match 323 of 7268.
# Error processing match 323: Not a ranked game. Skipping this match.
# Processing match 324 of 7268.
# Processing match 325 of 7268.
# Error processing match 325: Not a ranked game. Skipping this match.
# Processing match 326 of 7268.
# Processing match 327 of 7268.
# Processing match 328 of 7268.
# Processing match 329 of 7268.
# Processing match 330 of 7268.
# Error processing match 330: Not a ranked game. Skipping this match.
# Processing match 331 of 7268.
# Processing match 332 of 7268.
# Processing match 333 of 7268.
# Processing match 334 of 7268.
# Error processing match 334: Not a ranked game. Skipping this match.
# Processing match 335 of 7268.
# Processing match 336 of 7268.
# Processing match 337 of 7268.
# Processing match 338 of 7268.
# Processing match 339 of 7268.
# Error processing match 339: Not a ranked game. Skipping this match.
# Processing match 340 of 7268.
# Error processing match 340: Not a ranked game. Skipping this match.
# Processing match 341 of 7268.
# Processing match 342 of 7268.
# Error processing match 342: Not a ranked game. Skipping this match.
# Processing match 343 of 7268.
# Processing match 344 of 7268.
# Processing match 345 of 7268.
# Error processing match 345: Not a ranked game. Skipping this match.
# Processing match 346 of 7268.
# Processing match 347 of 7268.
# Error processing match 347: Not a ranked game. Skipping this match.
# Processing match 348 of 7268.
# Processing match 349 of 7268.
# Processing match 350 of 7268.
# Error processing match 350: Not a ranked game. Skipping this match.
# Processing match 351 of 7268.
# Error processing match 351: Not a ranked game. Skipping this match.
# Processing match 352 of 7268.
# Processing match 353 of 7268.
# Processing match 354 of 7268.
# Error processing match 354: Not a ranked game. Skipping this match.
# Processing match 355 of 7268.
# Processing match 356 of 7268.
# Processing match 357 of 7268.
# Processing match 358 of 7268.
# Processing match 359 of 7268.
# Processing match 360 of 7268.
# Processing match 361 of 7268.
# Processing match 362 of 7268.
# Processing match 363 of 7268.
# Processing match 364 of 7268.
# Processing match 365 of 7268.
# Error processing match 365: Not a ranked game. Skipping this match.
# Processing match 366 of 7268.
# Processing match 367 of 7268.
# Error processing match 367: Not a ranked game. Skipping this match.
# Processing match 368 of 7268.
# Processing match 369 of 7268.
# Error processing match 369: Not a ranked game. Skipping this match.
# Processing match 370 of 7268.
# Processing match 371 of 7268.
# Processing match 372 of 7268.
# Processing match 373 of 7268.
# Error processing match 373: Not a ranked game. Skipping this match.
# Processing match 374 of 7268.
# Processing match 375 of 7268.
# Processing match 376 of 7268.
# Processing match 377 of 7268.
# Processing match 378 of 7268.
# Processing match 379 of 7268.
# Processing match 380 of 7268.
# Processing match 381 of 7268.
# Processing match 382 of 7268.
# Error processing match 382: Not a ranked game. Skipping this match.
# Processing match 383 of 7268.
# Processing match 384 of 7268.
# Processing match 385 of 7268.
# Processing match 386 of 7268.
# Error processing match 386: Not a ranked game. Skipping this match.
# Processing match 387 of 7268.
# Error processing match 387: Not a ranked game. Skipping this match.
# Processing match 388 of 7268.
# Processing match 389 of 7268.
# Processing match 390 of 7268.
# Error processing match 390: Not a ranked game. Skipping this match.
# Processing match 391 of 7268.
# Error processing match 391: Not a ranked game. Skipping this match.
# Processing match 392 of 7268.
# Processing match 393 of 7268.
# Processing match 394 of 7268.
# Processing match 395 of 7268.
# Processing match 396 of 7268.
# Processing match 397 of 7268.
# Error processing match 397: Not a ranked game. Skipping this match.
# Processing match 398 of 7268.
# Processing match 399 of 7268.
# Processing match 400 of 7268.
# Processing match 401 of 7268.
# Processing match 402 of 7268.
# Processing match 403 of 7268.
# Error processing match 403: Not a ranked game. Skipping this match.
# Processing match 404 of 7268.
# Processing match 405 of 7268.
# Error processing match 405: Not a ranked game. Skipping this match.
# Processing match 406 of 7268.
# Processing match 407 of 7268.
# Processing match 408 of 7268.
# Processing match 409 of 7268.
# Processing match 410 of 7268.
# Processing match 411 of 7268.
# Error processing match 411: Not a ranked game. Skipping this match.
# Processing match 412 of 7268.
# Processing match 413 of 7268.
# Processing match 414 of 7268.
# Error processing match 414: Not a ranked game. Skipping this match.
# Processing match 415 of 7268.
# Processing match 416 of 7268.
# Processing match 417 of 7268.
# Processing match 418 of 7268.
# Processing match 419 of 7268.
# Error processing match 419: Not a ranked game. Skipping this match.
# Processing match 420 of 7268.
# Processing match 421 of 7268.
# Processing match 422 of 7268.
# Processing match 423 of 7268.
# Processing match 424 of 7268.
# Processing match 425 of 7268.
# Processing match 426 of 7268.
# Processing match 427 of 7268.
# Processing match 428 of 7268.
# Processing match 429 of 7268.
# Error processing match 429: Not a ranked game. Skipping this match.
# Processing match 430 of 7268.
# Processing match 431 of 7268.
# Processing match 432 of 7268.
# Processing match 433 of 7268.
# Error processing match 433: Not a ranked game. Skipping this match.
# Processing match 434 of 7268.
# Error processing match 434: Not a ranked game. Skipping this match.
# Processing match 435 of 7268.
# Error processing match 435: Not a ranked game. Skipping this match.
# Processing match 436 of 7268.
# Processing match 437 of 7268.
# Error processing match 437: Not a ranked game. Skipping this match.
# Processing match 438 of 7268.
# Error processing match 438: Not a ranked game. Skipping this match.
# Processing match 439 of 7268.
# Processing match 440 of 7268.
# Error processing match 440: Not a ranked game. Skipping this match.
# Processing match 441 of 7268.
# Processing match 442 of 7268.
# Processing match 443 of 7268.
# Processing match 444 of 7268.
# Processing match 445 of 7268.
# Processing match 446 of 7268.
# Processing match 447 of 7268.
# Error processing match 447: Not a ranked game. Skipping this match.
# Processing match 448 of 7268.
# Processing match 449 of 7268.
# Processing match 450 of 7268.
# Error processing match 450: Not a ranked game. Skipping this match.
# Processing match 451 of 7268.
# Processing match 452 of 7268.
# Processing match 453 of 7268.
# Processing match 454 of 7268.
# Processing match 455 of 7268.
# Error processing match 455: Not a ranked game. Skipping this match.
# Processing match 456 of 7268.
# Error processing match 456: Not a ranked game. Skipping this match.
# Processing match 457 of 7268.
# Processing match 458 of 7268.
# Processing match 459 of 7268.
# Processing match 460 of 7268.
# Error processing match 460: Not a ranked game. Skipping this match.
# Processing match 461 of 7268.
# Processing match 462 of 7268.
# Error processing match 462: Game too short. Skipping this match.
# Processing match 463 of 7268.
# Processing match 464 of 7268.
# Processing match 465 of 7268.
# Processing match 466 of 7268.
# Error processing match 466: Not a ranked game. Skipping this match.
# Processing match 467 of 7268.
# Error processing match 467: Not a ranked game. Skipping this match.
# Processing match 468 of 7268.
# Error processing match 468: Not a ranked game. Skipping this match.
# Processing match 469 of 7268.
# Processing match 470 of 7268.
# Error processing match 470: Not a ranked game. Skipping this match.
# Processing match 471 of 7268.
# Error processing match 471: Not a ranked game. Skipping this match.
# Processing match 472 of 7268.
# Error processing match 472: Game too short. Skipping this match.
# Processing match 473 of 7268.
# Processing match 474 of 7268.
# Processing match 475 of 7268.
# Error processing match 475: Not a ranked game. Skipping this match.
# Processing match 476 of 7268.
# Error processing match 476: Not a ranked game. Skipping this match.
# Processing match 477 of 7268.
# Processing match 478 of 7268.
# Processing match 479 of 7268.
# Processing match 480 of 7268.
# Processing match 481 of 7268.
# Processing match 482 of 7268.
# Processing match 483 of 7268.
# Error processing match 483: Not a ranked game. Skipping this match.
# Processing match 484 of 7268.
# Processing match 485 of 7268.
# Processing match 486 of 7268.
# Processing match 487 of 7268.
# Processing match 488 of 7268.
# Error processing match 488: Not a ranked game. Skipping this match.
# Processing match 489 of 7268.
# Processing match 490 of 7268.
# Error processing match 490: Not a ranked game. Skipping this match.
# Processing match 491 of 7268.
# Error processing match 491: Not a ranked game. Skipping this match.
# Processing match 492 of 7268.
# Processing match 493 of 7268.
# Processing match 494 of 7268.
# Error processing match 494: Not a ranked game. Skipping this match.
# Processing match 495 of 7268.
# Error processing match 495: Not a ranked game. Skipping this match.
# Processing match 496 of 7268.
# Processing match 497 of 7268.
# Processing match 498 of 7268.
# Processing match 499 of 7268.
# Processing match 500 of 7268.
# Error processing match 500: Not a ranked game. Skipping this match.
# Processing match 501 of 7268.
# Processing match 502 of 7268.
# Processing match 503 of 7268.
# Processing match 504 of 7268.
# Error processing match 504: Not a ranked game. Skipping this match.
# Processing match 505 of 7268.
# Processing match 506 of 7268.
# Processing match 507 of 7268.
# Processing match 508 of 7268.
# Error processing match 508: Not a ranked game. Skipping this match.
# Processing match 509 of 7268.
# Processing match 510 of 7268.
# Error processing match 510: Not a ranked game. Skipping this match.
# Processing match 511 of 7268.
# Processing match 512 of 7268.
# Processing match 513 of 7268.
# Error processing match 513: Not a ranked game. Skipping this match.
# Processing match 514 of 7268.
# Processing match 515 of 7268.
# Error processing match 515: Not a ranked game. Skipping this match.
# Processing match 516 of 7268.
# Error processing match 516: Not a ranked game. Skipping this match.
# Processing match 517 of 7268.
# Error processing match 517: Not a ranked game. Skipping this match.
# Processing match 518 of 7268.
# Error processing match 518: Not a ranked game. Skipping this match.
# Processing match 519 of 7268.
# Error processing match 519: Not a ranked game. Skipping this match.
# Processing match 520 of 7268.
# Error processing match 520: Not a ranked game. Skipping this match.
# Processing match 521 of 7268.
# Error processing match 521: Not a ranked game. Skipping this match.
# Processing match 522 of 7268.
# Processing match 523 of 7268.
# Error processing match 523: Not a ranked game. Skipping this match.
# Processing match 524 of 7268.
# Error processing match 524: Not a ranked game. Skipping this match.
# Processing match 525 of 7268.
# Error processing match 525: Not a ranked game. Skipping this match.
# Processing match 526 of 7268.
# Processing match 527 of 7268.
# Error processing match 527: Game too short. Skipping this match.
# Processing match 528 of 7268.
# Error processing match 528: Not a ranked game. Skipping this match.
# Processing match 529 of 7268.
# Processing match 530 of 7268.
# Processing match 531 of 7268.
# Error processing match 531: Not a ranked game. Skipping this match.
# Processing match 532 of 7268.
# Processing match 533 of 7268.
# Error processing match 533: Not a ranked game. Skipping this match.
# Processing match 534 of 7268.
# Processing match 535 of 7268.
# Error processing match 535: Not a ranked game. Skipping this match.
# Processing match 536 of 7268.
# Processing match 537 of 7268.
# Processing match 538 of 7268.
# Processing match 539 of 7268.
# Processing match 540 of 7268.
# Error processing match 540: Not a ranked game. Skipping this match.
# Processing match 541 of 7268.
# Processing match 542 of 7268.
# Processing match 543 of 7268.
# Processing match 544 of 7268.
# Processing match 545 of 7268.
# Processing match 546 of 7268.
# Error processing match 546: Not a ranked game. Skipping this match.
# Processing match 547 of 7268.
# Processing match 548 of 7268.
# Processing match 549 of 7268.
# Processing match 550 of 7268.
# Processing match 551 of 7268.
# Error processing match 551: Not a ranked game. Skipping this match.
# Processing match 552 of 7268.
# Processing match 553 of 7268.
# Processing match 554 of 7268.
# Error processing match 554: Not a ranked game. Skipping this match.
# Processing match 555 of 7268.
# Processing match 556 of 7268.
# Error processing match 556: Not a ranked game. Skipping this match.
# Processing match 557 of 7268.
# Processing match 558 of 7268.
# Processing match 559 of 7268.
# Error processing match 559: Not a ranked game. Skipping this match.
# Processing match 560 of 7268.
# Processing match 561 of 7268.
# Error processing match 561: Not a ranked game. Skipping this match.
# Processing match 562 of 7268.
# Processing match 563 of 7268.
# Processing match 564 of 7268.
# Processing match 565 of 7268.
# Processing match 566 of 7268.
# Processing match 567 of 7268.
# Processing match 568 of 7268.
# Error processing match 568: Game too short. Skipping this match.
# Processing match 569 of 7268.
# Error processing match 569: Not a ranked game. Skipping this match.
# Processing match 570 of 7268.
# Processing match 571 of 7268.
# Processing match 572 of 7268.
# Error processing match 572: Not a ranked game. Skipping this match.
# Processing match 573 of 7268.
# Error processing match 573: Not a ranked game. Skipping this match.
# Processing match 574 of 7268.
# Error processing match 574: Not a ranked game. Skipping this match.
# Processing match 575 of 7268.
# Error processing match 575: Not a ranked game. Skipping this match.
# Processing match 576 of 7268.
# Processing match 577 of 7268.
# Processing match 578 of 7268.
# Processing match 579 of 7268.
# Processing match 580 of 7268.
# Processing match 581 of 7268.
# Processing match 582 of 7268.
# Error processing match 582: Not a ranked game. Skipping this match.
# Processing match 583 of 7268.
# Processing match 584 of 7268.
# Processing match 585 of 7268.
# Error processing match 585: Not a ranked game. Skipping this match.
# Processing match 586 of 7268.
# Processing match 587 of 7268.
# Processing match 588 of 7268.
# Processing match 589 of 7268.
# Processing match 590 of 7268.
# Error processing match 590: Not a ranked game. Skipping this match.
# Processing match 591 of 7268.
# Processing match 592 of 7268.
# Processing match 593 of 7268.
# Processing match 594 of 7268.
# Processing match 595 of 7268.
# Error processing match 595: Not a ranked game. Skipping this match.
# Processing match 596 of 7268.
# Error processing match 596: Not a ranked game. Skipping this match.
# Processing match 597 of 7268.
# Error processing match 597: Not a ranked game. Skipping this match.
# Processing match 598 of 7268.
# Processing match 599 of 7268.
# Processing match 600 of 7268.
# Error processing match 600: Not a ranked game. Skipping this match.
# Processing match 601 of 7268.
# Processing match 602 of 7268.
# Error processing match 602: Not a ranked game. Skipping this match.
# Processing match 603 of 7268.
# Processing match 604 of 7268.
# Processing match 605 of 7268.
# Error processing match 605: Not a ranked game. Skipping this match.
# Processing match 606 of 7268.
# Error processing match 606: Not a ranked game. Skipping this match.
# Processing match 607 of 7268.
# Processing match 608 of 7268.
# Processing match 609 of 7268.
# Error processing match 609: Not a ranked game. Skipping this match.
# Processing match 610 of 7268.
# Processing match 611 of 7268.
# Processing match 612 of 7268.
# Error processing match 612: Not a ranked game. Skipping this match.
# Processing match 613 of 7268.
# Processing match 614 of 7268.
# Processing match 615 of 7268.
# Processing match 616 of 7268.
# Processing match 617 of 7268.
# Processing match 618 of 7268.
# Error processing match 618: Not a ranked game. Skipping this match.
# Processing match 619 of 7268.
# Error processing match 619: Not a ranked game. Skipping this match.
# Processing match 620 of 7268.
# Processing match 621 of 7268.
# Processing match 622 of 7268.
# Processing match 623 of 7268.
# Processing match 624 of 7268.
# Error processing match 624: Not a ranked game. Skipping this match.
# Processing match 625 of 7268.
# Processing match 626 of 7268.
# Processing match 627 of 7268.
# Processing match 628 of 7268.
# Processing match 629 of 7268.
# Processing match 630 of 7268.
# Processing match 631 of 7268.
# Processing match 632 of 7268.
# Processing match 633 of 7268.
# Processing match 634 of 7268.
# Processing match 635 of 7268.
# Processing match 636 of 7268.
# Processing match 637 of 7268.
# Processing match 638 of 7268.
# Error processing match 638: Not a ranked game. Skipping this match.
# Processing match 639 of 7268.
# Processing match 640 of 7268.
# Processing match 641 of 7268.
# Processing match 642 of 7268.
# Error processing match 642: Not a ranked game. Skipping this match.
# Processing match 643 of 7268.
# Error processing match 643: Not a ranked game. Skipping this match.
# Processing match 644 of 7268.
# Processing match 645 of 7268.
# Error processing match 645: Not a ranked game. Skipping this match.
# Processing match 646 of 7268.
# Error processing match 646: Not a ranked game. Skipping this match.
# Processing match 647 of 7268.
# Processing match 648 of 7268.
# Error processing match 648: Game too short. Skipping this match.
# Processing match 649 of 7268.
# Processing match 650 of 7268.
# Processing match 651 of 7268.
# Processing match 652 of 7268.
# Processing match 653 of 7268.
# Processing match 654 of 7268.
# Processing match 655 of 7268.
# Error processing match 655: Not a ranked game. Skipping this match.
# Processing match 656 of 7268.
# Error processing match 656: Not a ranked game. Skipping this match.
# Processing match 657 of 7268.
# Error processing match 657: Not a ranked game. Skipping this match.
# Processing match 658 of 7268.
# Processing match 659 of 7268.
# Processing match 660 of 7268.
# Error processing match 660: Not a ranked game. Skipping this match.
# Processing match 661 of 7268.
# Error processing match 661: Not a ranked game. Skipping this match.
# Processing match 662 of 7268.
# Processing match 663 of 7268.
# Processing match 664 of 7268.
# Error processing match 664: Not a ranked game. Skipping this match.
# Processing match 665 of 7268.
# Error processing match 665: Not a ranked game. Skipping this match.
# Processing match 666 of 7268.
# Processing match 667 of 7268.
# Error processing match 667: Not a ranked game. Skipping this match.
# Processing match 668 of 7268.
# Processing match 669 of 7268.
# Processing match 670 of 7268.
# Processing match 671 of 7268.
# Error processing match 671: Not a ranked game. Skipping this match.
# Processing match 672 of 7268.
# Error processing match 672: Not a ranked game. Skipping this match.
# Processing match 673 of 7268.
# Processing match 674 of 7268.
# Processing match 675 of 7268.
# Error processing match 675: Not a ranked game. Skipping this match.
# Processing match 676 of 7268.
# Error processing match 676: Not a ranked game. Skipping this match.
# Processing match 677 of 7268.
# Processing match 678 of 7268.
# Processing match 679 of 7268.
# Processing match 680 of 7268.
# Processing match 681 of 7268.
# Error processing match 681: Not a ranked game. Skipping this match.
# Processing match 682 of 7268.
# Error processing match 682: Not a ranked game. Skipping this match.
# Processing match 683 of 7268.
# Error processing match 683: Not a ranked game. Skipping this match.
# Processing match 684 of 7268.
# Error processing match 684: Not a ranked game. Skipping this match.
# Processing match 685 of 7268.
# Error processing match 685: Not a ranked game. Skipping this match.
# Processing match 686 of 7268.
# Error processing match 686: Not a ranked game. Skipping this match.
# Processing match 687 of 7268.
# Error processing match 687: Not a ranked game. Skipping this match.
# Processing match 688 of 7268.
# Error processing match 688: Not a ranked game. Skipping this match.
# Processing match 689 of 7268.
# Processing match 690 of 7268.
# Error processing match 690: Not a ranked game. Skipping this match.
# Processing match 691 of 7268.
# Error processing match 691: Not a ranked game. Skipping this match.
# Processing match 692 of 7268.
# Error processing match 692: Not a ranked game. Skipping this match.
# Processing match 693 of 7268.
# Processing match 694 of 7268.
# Error processing match 694: Not a ranked game. Skipping this match.
# Processing match 695 of 7268.
# Processing match 696 of 7268.
# Processing match 697 of 7268.
# Error processing match 697: Not a ranked game. Skipping this match.
# Processing match 698 of 7268.
# Processing match 699 of 7268.
# Error processing match 699: Not a ranked game. Skipping this match.
# Processing match 700 of 7268.
# Error processing match 700: Not a ranked game. Skipping this match.
# Processing match 701 of 7268.
# Processing match 702 of 7268.
# Error processing match 702: Not a ranked game. Skipping this match.
# Processing match 703 of 7268.
# Processing match 704 of 7268.
# Error processing match 704: Not a ranked game. Skipping this match.
# Processing match 705 of 7268.
# Error processing match 705: Not a ranked game. Skipping this match.
# Processing match 706 of 7268.
# Processing match 707 of 7268.
# Error processing match 707: Not a ranked game. Skipping this match.
# Processing match 708 of 7268.
# Processing match 709 of 7268.
# Error processing match 709: Not a ranked game. Skipping this match.
# Processing match 710 of 7268.
# Error processing match 710: Not a ranked game. Skipping this match.
# Processing match 711 of 7268.
# Processing match 712 of 7268.
# Processing match 713 of 7268.
# Processing match 714 of 7268.
# Processing match 715 of 7268.
# Processing match 716 of 7268.
# Error processing match 716: Not a ranked game. Skipping this match.
# Processing match 717 of 7268.
# Processing match 718 of 7268.
# Processing match 719 of 7268.
# Processing match 720 of 7268.
# Error processing match 720: Not a ranked game. Skipping this match.
# Processing match 721 of 7268.
# Processing match 722 of 7268.
# Processing match 723 of 7268.
# Error processing match 723: Not a ranked game. Skipping this match.
# Processing match 724 of 7268.
# Error processing match 724: Not a ranked game. Skipping this match.
# Processing match 725 of 7268.
# Error processing match 725: Not a ranked game. Skipping this match.
# Processing match 726 of 7268.
# Processing match 727 of 7268.
# Processing match 728 of 7268.
# Processing match 729 of 7268.
# Processing match 730 of 7268.
# Error processing match 730: Not a ranked game. Skipping this match.
# Processing match 731 of 7268.
# Processing match 732 of 7268.
# Processing match 733 of 7268.
# Processing match 734 of 7268.
# Processing match 735 of 7268.
# Processing match 736 of 7268.
# Error processing match 736: Not a ranked game. Skipping this match.
# Processing match 737 of 7268.
# Error processing match 737: Not a ranked game. Skipping this match.
# Processing match 738 of 7268.
# Processing match 739 of 7268.
# Processing match 740 of 7268.
# Processing match 741 of 7268.
# Processing match 742 of 7268.
# Processing match 743 of 7268.
# Processing match 744 of 7268.
# Processing match 745 of 7268.
# Processing match 746 of 7268.
# Processing match 747 of 7268.
# Error processing match 747: Not a ranked game. Skipping this match.
# Processing match 748 of 7268.
# Processing match 749 of 7268.
# Processing match 750 of 7268.
# Error processing match 750: Not a ranked game. Skipping this match.
# Processing match 751 of 7268.
# Error processing match 751: Not a ranked game. Skipping this match.
# Processing match 752 of 7268.
# Error processing match 752: Game too short. Skipping this match.
# Processing match 753 of 7268.
# Processing match 754 of 7268.
# Processing match 755 of 7268.
# Processing match 756 of 7268.
# Error processing match 756: Not a ranked game. Skipping this match.
# Processing match 757 of 7268.
# Processing match 758 of 7268.
# Error processing match 758: Not a ranked game. Skipping this match.
# Processing match 759 of 7268.
# Processing match 760 of 7268.
# Error processing match 760: Not a ranked game. Skipping this match.
# Processing match 761 of 7268.
# Processing match 762 of 7268.
# Processing match 763 of 7268.
# Processing match 764 of 7268.
# Error processing match 764: Not a ranked game. Skipping this match.
# Processing match 765 of 7268.
# Processing match 766 of 7268.
# Processing match 767 of 7268.
# Error processing match 767: Game too short. Skipping this match.
# Processing match 768 of 7268.
# Processing match 769 of 7268.
# Processing match 770 of 7268.
# Error processing match 770: Not a ranked game. Skipping this match.
# Processing match 771 of 7268.
# Processing match 772 of 7268.
# Processing match 773 of 7268.
# Processing match 774 of 7268.
# Processing match 775 of 7268.
# Processing match 776 of 7268.
# Processing match 777 of 7268.
# Processing match 778 of 7268.
# Processing match 779 of 7268.
# Error processing match 779: Not a ranked game. Skipping this match.
# Processing match 780 of 7268.
# Processing match 781 of 7268.
# Error processing match 781: Not a ranked game. Skipping this match.
# Processing match 782 of 7268.
# Processing match 783 of 7268.
# Processing match 784 of 7268.
# Error processing match 784: Not a ranked game. Skipping this match.
# Processing match 785 of 7268.
# Error processing match 785: Game too short. Skipping this match.
# Processing match 786 of 7268.
# Processing match 787 of 7268.
# Error processing match 787: Not a ranked game. Skipping this match.
# Processing match 788 of 7268.
# Processing match 789 of 7268.
# Error processing match 789: Not a ranked game. Skipping this match.
# Processing match 790 of 7268.
# Processing match 791 of 7268.
# Processing match 792 of 7268.
# Processing match 793 of 7268.
# Error processing match 793: Not a ranked game. Skipping this match.
# Processing match 794 of 7268.
# Processing match 795 of 7268.
# Error processing match 795: Not a ranked game. Skipping this match.
# Processing match 796 of 7268.
# Error processing match 796: Not a ranked game. Skipping this match.
# Processing match 797 of 7268.
# Processing match 798 of 7268.
# Processing match 799 of 7268.
# Processing match 800 of 7268.
# Processing match 801 of 7268.
# Processing match 802 of 7268.
# Processing match 803 of 7268.
# Processing match 804 of 7268.
# Error processing match 804: Not a ranked game. Skipping this match.
# Processing match 805 of 7268.
# Processing match 806 of 7268.
# Error processing match 806: Not a ranked game. Skipping this match.
# Processing match 807 of 7268.
# Processing match 808 of 7268.
# Processing match 809 of 7268.
# Error processing match 809: Not a ranked game. Skipping this match.
# Processing match 810 of 7268.
# Processing match 811 of 7268.
# Processing match 812 of 7268.
# Processing match 813 of 7268.
# Error processing match 813: Not a ranked game. Skipping this match.
# Processing match 814 of 7268.
# Processing match 815 of 7268.
# Processing match 816 of 7268.
# Error processing match 816: Not a ranked game. Skipping this match.
# Processing match 817 of 7268.
# Error processing match 817: Not a ranked game. Skipping this match.
# Processing match 818 of 7268.
# Processing match 819 of 7268.
# Error processing match 819: Not a ranked game. Skipping this match.
# Processing match 820 of 7268.
# Error processing match 820: Not a ranked game. Skipping this match.
# Processing match 821 of 7268.
# Error processing match 821: Not a ranked game. Skipping this match.
# Processing match 822 of 7268.
# Error processing match 822: Not a ranked game. Skipping this match.
# Processing match 823 of 7268.
# Processing match 824 of 7268.
# Processing match 825 of 7268.
# Processing match 826 of 7268.
# Error processing match 826: Not a ranked game. Skipping this match.
# Processing match 827 of 7268.
# Error processing match 827: Not a ranked game. Skipping this match.
# Processing match 828 of 7268.
# Processing match 829 of 7268.
# Error processing match 829: Not a ranked game. Skipping this match.
# Processing match 830 of 7268.
# Error processing match 830: Not a ranked game. Skipping this match.
# Processing match 831 of 7268.
# Processing match 832 of 7268.
# Processing match 833 of 7268.
# Processing match 834 of 7268.
# Error processing match 834: Not a ranked game. Skipping this match.
# Processing match 835 of 7268.
# Processing match 836 of 7268.
# Error processing match 836: Not a ranked game. Skipping this match.
# Processing match 837 of 7268.
# Processing match 838 of 7268.
# Error processing match 838: Not a ranked game. Skipping this match.
# Processing match 839 of 7268.
# Error processing match 839: Not a ranked game. Skipping this match.
# Processing match 840 of 7268.
# Processing match 841 of 7268.
# Processing match 842 of 7268.
# Error processing match 842: Not a ranked game. Skipping this match.
# Processing match 843 of 7268.
# Processing match 844 of 7268.
# Processing match 845 of 7268.
# Error processing match 845: Not a ranked game. Skipping this match.
# Processing match 846 of 7268.
# Error processing match 846: Not a ranked game. Skipping this match.
# Processing match 847 of 7268.
# Error processing match 847: Not a ranked game. Skipping this match.
# Processing match 848 of 7268.
# Processing match 849 of 7268.
# Processing match 850 of 7268.
# Processing match 851 of 7268.
# Processing match 852 of 7268.
# Processing match 853 of 7268.
# Processing match 854 of 7268.
# Processing match 855 of 7268.
# Error processing match 855: Not a ranked game. Skipping this match.
# Processing match 856 of 7268.
# Processing match 857 of 7268.
# Processing match 858 of 7268.
# Processing match 859 of 7268.
# Error processing match 859: Not a ranked game. Skipping this match.
# Processing match 860 of 7268.
# Processing match 861 of 7268.
# Error processing match 861: Not a ranked game. Skipping this match.
# Processing match 862 of 7268.
# Error processing match 862: Not a ranked game. Skipping this match.
# Processing match 863 of 7268.
# Error processing match 863: Not a ranked game. Skipping this match.
# Processing match 864 of 7268.
# Processing match 865 of 7268.
# Processing match 866 of 7268.
# Processing match 867 of 7268.
# Processing match 868 of 7268.
# Processing match 869 of 7268.
# Processing match 870 of 7268.
# Processing match 871 of 7268.
# Error processing match 871: Game too short. Skipping this match.
# Processing match 872 of 7268.
# Error processing match 872: Not a ranked game. Skipping this match.
# Processing match 873 of 7268.
# Error processing match 873: Not a ranked game. Skipping this match.
# Processing match 874 of 7268.
# Processing match 875 of 7268.
# Processing match 876 of 7268.
# Processing match 877 of 7268.
# Processing match 878 of 7268.
# Processing match 879 of 7268.
# Error processing match 879: Not a ranked game. Skipping this match.
# Processing match 880 of 7268.
# Processing match 881 of 7268.
# Processing match 882 of 7268.
# Processing match 883 of 7268.
# Error processing match 883: Game too short. Skipping this match.
# Processing match 884 of 7268.
# Error processing match 884: Not a ranked game. Skipping this match.
# Processing match 885 of 7268.
# Error processing match 885: Not a ranked game. Skipping this match.
# Processing match 886 of 7268.
# Processing match 887 of 7268.
# Processing match 888 of 7268.
# Processing match 889 of 7268.
# Processing match 890 of 7268.
# ...
# Processing match 6971 of 7268.
# Processing match 6972 of 7268.
# Processing match 6973 of 7268.
# Processing match 6974 of 7268.
# Processing match 6975 of 7268.
# Processing match 6976 of 7268.
# Error processing match 6976: Not a ranked game. Skipping this match.
# Processing match 6977 of 7268.
# Error processing match 6977: Not a ranked game. Skipping this match.
# Processing match 6978 of 7268.
# Processing match 6979 of 7268.
# Processing match 6980 of 7268.
# Processing match 6981 of 7268.
# Error processing match 6981: Not a ranked game. Skipping this match.
# Processing match 6982 of 7268.
# Error processing match 6982: Not a ranked game. Skipping this match.
# Processing match 6983 of 7268.
# Processing match 6984 of 7268.
# Processing match 6985 of 7268.
# Error processing match 6985: Not a ranked game. Skipping this match.
# Processing match 6986 of 7268.
# Processing match 6987 of 7268.
# Processing match 6988 of 7268.
# Error processing match 6988: Not a ranked game. Skipping this match.
# Processing match 6989 of 7268.
# Processing match 6990 of 7268.
# Error processing match 6990: Not a ranked game. Skipping this match.
# Processing match 6991 of 7268.
# Processing match 6992 of 7268.
# Processing match 6993 of 7268.
# Processing match 6994 of 7268.
# Error processing match 6994: Not a ranked game. Skipping this match.
# Processing match 6995 of 7268.
# Processing match 6996 of 7268.
# Processing match 6997 of 7268.
# Error processing match 6997: Not a ranked game. Skipping this match.
# Processing match 6998 of 7268.
# Processing match 6999 of 7268.
# Processing match 7000 of 7268.
# Processing match 7001 of 7268.
# Processing match 7002 of 7268.
# Error processing match 7002: Not a ranked game. Skipping this match.
# Processing match 7003 of 7268.
# Error processing match 7003: Not a ranked game. Skipping this match.
# Processing match 7004 of 7268.
# Processing match 7005 of 7268.
# Processing match 7006 of 7268.
# Error processing match 7006: Not a ranked game. Skipping this match.
# Processing match 7007 of 7268.
# Processing match 7008 of 7268.
# Processing match 7009 of 7268.
# Error processing match 7009: Not a ranked game. Skipping this match.
# Processing match 7010 of 7268.
# Processing match 7011 of 7268.
# Processing match 7012 of 7268.
# Processing match 7013 of 7268.
# Processing match 7014 of 7268.
# Processing match 7015 of 7268.
# Processing match 7016 of 7268.
# Processing match 7017 of 7268.
# Processing match 7018 of 7268.
# Processing match 7019 of 7268.
# Processing match 7020 of 7268.
# Processing match 7021 of 7268.
# Processing match 7022 of 7268.
# Error processing match 7022: Not a ranked game. Skipping this match.
# Processing match 7023 of 7268.
# Processing match 7024 of 7268.
# Processing match 7025 of 7268.
# Error processing match 7025: Not a ranked game. Skipping this match.
# Processing match 7026 of 7268.
# Processing match 7027 of 7268.
# Processing match 7028 of 7268.
# Processing match 7029 of 7268.
# Processing match 7030 of 7268.
# Processing match 7031 of 7268.
# Error processing match 7031: Not a ranked game. Skipping this match.
# Processing match 7032 of 7268.
# Processing match 7033 of 7268.
# Processing match 7034 of 7268.
# Processing match 7035 of 7268.
# Error processing match 7035: Not a ranked game. Skipping this match.
# Processing match 7036 of 7268.
# Processing match 7037 of 7268.
# Processing match 7038 of 7268.
# Processing match 7039 of 7268.
# Processing match 7040 of 7268.
# Processing match 7041 of 7268.
# Error processing match 7041: Not a ranked game. Skipping this match.
# Processing match 7042 of 7268.
# Processing match 7043 of 7268.
# Processing match 7044 of 7268.
# Processing match 7045 of 7268.
# Processing match 7046 of 7268.
# Error processing match 7046: Not a ranked game. Skipping this match.
# Processing match 7047 of 7268.
# Error processing match 7047: Not a ranked game. Skipping this match.
# Processing match 7048 of 7268.
# Processing match 7049 of 7268.
# Processing match 7050 of 7268.
# Error processing match 7050: Not a ranked game. Skipping this match.
# Processing match 7051 of 7268.
# Processing match 7052 of 7268.
# Processing match 7053 of 7268.
# Processing match 7054 of 7268.
# Error processing match 7054: Not a ranked game. Skipping this match.
# Processing match 7055 of 7268.
# Processing match 7056 of 7268.
# Processing match 7057 of 7268.
# Processing match 7058 of 7268.
# Processing match 7059 of 7268.
# Error processing match 7059: Not a ranked game. Skipping this match.
# Processing match 7060 of 7268.
# Processing match 7061 of 7268.
# Processing match 7062 of 7268.
# Processing match 7063 of 7268.
# Processing match 7064 of 7268.
# Processing match 7065 of 7268.
# Processing match 7066 of 7268.
# Processing match 7067 of 7268.
# Processing match 7068 of 7268.
# Processing match 7069 of 7268.
# Processing match 7070 of 7268.
# Processing match 7071 of 7268.
# Error processing match 7071: Not a ranked game. Skipping this match.
# Processing match 7072 of 7268.
# Processing match 7073 of 7268.
# Error processing match 7073: Not a ranked game. Skipping this match.
# Processing match 7074 of 7268.
# Processing match 7075 of 7268.
# Processing match 7076 of 7268.
# Processing match 7077 of 7268.
# Error processing match 7077: Not a ranked game. Skipping this match.
# Processing match 7078 of 7268.
# Processing match 7079 of 7268.
# Processing match 7080 of 7268.
# Processing match 7081 of 7268.
# Processing match 7082 of 7268.
# Error processing match 7082: Game too short. Skipping this match.
# Processing match 7083 of 7268.
# Processing match 7084 of 7268.
# Processing match 7085 of 7268.
# Error processing match 7085: Not a ranked game. Skipping this match.
# Processing match 7086 of 7268.
# Error processing match 7086: Not a ranked game. Skipping this match.
# Processing match 7087 of 7268.
# Processing match 7088 of 7268.
# Processing match 7089 of 7268.
# Error processing match 7089: Not a ranked game. Skipping this match.
# Processing match 7090 of 7268.
# Processing match 7091 of 7268.
# Processing match 7092 of 7268.
# Error processing match 7092: Not a ranked game. Skipping this match.
# Processing match 7093 of 7268.
# Error processing match 7093: Not a ranked game. Skipping this match.
# Processing match 7094 of 7268.
# Error processing match 7094: Not a ranked game. Skipping this match.
# Processing match 7095 of 7268.
# Error processing match 7095: Not a ranked game. Skipping this match.
# Processing match 7096 of 7268.
# Processing match 7097 of 7268.
# Error processing match 7097: Not a ranked game. Skipping this match.
# Processing match 7098 of 7268.
# Processing match 7099 of 7268.
# Processing match 7100 of 7268.
# Error processing match 7100: Not a ranked game. Skipping this match.
# Processing match 7101 of 7268.
# Processing match 7102 of 7268.
# Processing match 7103 of 7268.
# Processing match 7104 of 7268.
# Error processing match 7104: Not a ranked game. Skipping this match.
# Processing match 7105 of 7268.
# Error processing match 7105: Not a ranked game. Skipping this match.
# Processing match 7106 of 7268.
# Error processing match 7106: Not a ranked game. Skipping this match.
# Processing match 7107 of 7268.
# Error processing match 7107: Not a ranked game. Skipping this match.
# Processing match 7108 of 7268.
# Processing match 7109 of 7268.
# Processing match 7110 of 7268.
# Processing match 7111 of 7268.
# Processing match 7112 of 7268.
# Error processing match 7112: Not a ranked game. Skipping this match.
# Processing match 7113 of 7268.
# Processing match 7114 of 7268.
# Error processing match 7114: Not a ranked game. Skipping this match.
# Processing match 7115 of 7268.
# Processing match 7116 of 7268.
# Error processing match 7116: Not a ranked game. Skipping this match.
# Processing match 7117 of 7268.
# Processing match 7118 of 7268.
# Processing match 7119 of 7268.
# Processing match 7120 of 7268.
# Processing match 7121 of 7268.
# Processing match 7122 of 7268.
# Processing match 7123 of 7268.
# Processing match 7124 of 7268.
# Error processing match 7124: Not a ranked game. Skipping this match.
# Processing match 7125 of 7268.
# Error processing match 7125: Not a ranked game. Skipping this match.
# Processing match 7126 of 7268.
# Processing match 7127 of 7268.
# Processing match 7128 of 7268.
# Error processing match 7128: Not a ranked game. Skipping this match.
# Processing match 7129 of 7268.
# Error processing match 7129: Not a ranked game. Skipping this match.
# Processing match 7130 of 7268.
# Error processing match 7130: Not a ranked game. Skipping this match.
# Processing match 7131 of 7268.
# Error processing match 7131: Game too short. Skipping this match.
# Processing match 7132 of 7268.
# Processing match 7133 of 7268.
# Error processing match 7133: Not a ranked game. Skipping this match.
# Processing match 7134 of 7268.
# Error processing match 7134: Not a ranked game. Skipping this match.
# Processing match 7135 of 7268.
# Processing match 7136 of 7268.
# Processing match 7137 of 7268.
# Processing match 7138 of 7268.
# Processing match 7139 of 7268.
# Processing match 7140 of 7268.
# Processing match 7141 of 7268.
# Error processing match 7141: Not a ranked game. Skipping this match.
# Processing match 7142 of 7268.
# Error processing match 7142: Not a ranked game. Skipping this match.
# Processing match 7143 of 7268.
# Processing match 7144 of 7268.
# Processing match 7145 of 7268.
# Processing match 7146 of 7268.
# Error processing match 7146: Not a ranked game. Skipping this match.
# Processing match 7147 of 7268.
# Processing match 7148 of 7268.
# Error processing match 7148: Not a ranked game. Skipping this match.
# Processing match 7149 of 7268.
# Processing match 7150 of 7268.
# Error processing match 7150: Not a ranked game. Skipping this match.
# Processing match 7151 of 7268.
# Processing match 7152 of 7268.
# Processing match 7153 of 7268.
# Error processing match 7153: Not a ranked game. Skipping this match.
# Processing match 7154 of 7268.
# Processing match 7155 of 7268.
# Processing match 7156 of 7268.
# Processing match 7157 of 7268.
# Processing match 7158 of 7268.
# Processing match 7159 of 7268.
# Error processing match 7159: Not a ranked game. Skipping this match.
# Processing match 7160 of 7268.
# Error processing match 7160: Not a ranked game. Skipping this match.
# Processing match 7161 of 7268.
# Processing match 7162 of 7268.
# Processing match 7163 of 7268.
# Processing match 7164 of 7268.
# Error processing match 7164: Not a ranked game. Skipping this match.
# Processing match 7165 of 7268.
# Error processing match 7165: Not a ranked game. Skipping this match.
# Processing match 7166 of 7268.
# Processing match 7167 of 7268.
# Error processing match 7167: Not a ranked game. Skipping this match.
# Processing match 7168 of 7268.
# Processing match 7169 of 7268.
# Error processing match 7169: Not a ranked game. Skipping this match.
# Processing match 7170 of 7268.
# Processing match 7171 of 7268.
# Processing match 7172 of 7268.
# Processing match 7173 of 7268.
# Error processing match 7173: Not a ranked game. Skipping this match.
# Processing match 7174 of 7268.
# Processing match 7175 of 7268.
# Processing match 7176 of 7268.
# Error processing match 7176: Not a ranked game. Skipping this match.
# Processing match 7177 of 7268.
# Processing match 7178 of 7268.
# Processing match 7179 of 7268.
# Processing match 7180 of 7268.
# Error processing match 7180: Not a ranked game. Skipping this match.
# Processing match 7181 of 7268.
# Processing match 7182 of 7268.
# Error processing match 7182: Not a ranked game. Skipping this match.
# Processing match 7183 of 7268.
# Processing match 7184 of 7268.
# Processing match 7185 of 7268.
# Error processing match 7185: Not a ranked game. Skipping this match.
# Processing match 7186 of 7268.
# Processing match 7187 of 7268.
# Processing match 7188 of 7268.
# Error processing match 7188: Not a ranked game. Skipping this match.
# Processing match 7189 of 7268.
# Processing match 7190 of 7268.
# Processing match 7191 of 7268.
# Processing match 7192 of 7268.
# Processing match 7193 of 7268.
# Processing match 7194 of 7268.
# Processing match 7195 of 7268.
# Error processing match 7195: Not a ranked game. Skipping this match.
# Processing match 7196 of 7268.
# Processing match 7197 of 7268.
# Error processing match 7197: Not a ranked game. Skipping this match.
# Processing match 7198 of 7268.
# Processing match 7199 of 7268.
# Processing match 7200 of 7268.
# Processing match 7201 of 7268.
# Processing match 7202 of 7268.
# Processing match 7203 of 7268.
# Error processing match 7203: Not a ranked game. Skipping this match.
# Processing match 7204 of 7268.
# Error processing match 7204: Not a ranked game. Skipping this match.
# Processing match 7205 of 7268.
# Error processing match 7205: Not a ranked game. Skipping this match.
# Processing match 7206 of 7268.
# Processing match 7207 of 7268.
# Processing match 7208 of 7268.
# Processing match 7209 of 7268.
# Processing match 7210 of 7268.
# Error processing match 7210: Not a ranked game. Skipping this match.
# Processing match 7211 of 7268.
# Error processing match 7211: Not a ranked game. Skipping this match.
# Processing match 7212 of 7268.
# Processing match 7213 of 7268.
# Processing match 7214 of 7268.
# Processing match 7215 of 7268.
# Processing match 7216 of 7268.
# Error processing match 7216: Not a ranked game. Skipping this match.
# Processing match 7217 of 7268.
# Processing match 7218 of 7268.
# Processing match 7219 of 7268.
# Processing match 7220 of 7268.
# Processing match 7221 of 7268.
# Processing match 7222 of 7268.
# Processing match 7223 of 7268.
# Processing match 7224 of 7268.
# Error processing match 7224: Not a ranked game. Skipping this match.
# Processing match 7225 of 7268.
# Processing match 7226 of 7268.
# Error processing match 7226: Not a ranked game. Skipping this match.
# Processing match 7227 of 7268.
# Processing match 7228 of 7268.
# Processing match 7229 of 7268.
# Processing match 7230 of 7268.
# Processing match 7231 of 7268.
# Processing match 7232 of 7268.
# Error processing match 7232: Not a ranked game. Skipping this match.
# Processing match 7233 of 7268.
# Error processing match 7233: Not a ranked game. Skipping this match.
# Processing match 7234 of 7268.
# Error processing match 7234: Not a ranked game. Skipping this match.
# Processing match 7235 of 7268.
# Processing match 7236 of 7268.
# Error processing match 7236: Not a ranked game. Skipping this match.
# Processing match 7237 of 7268.
# Error processing match 7237: Not a ranked game. Skipping this match.
# Processing match 7238 of 7268.
# Error processing match 7238: Not a ranked game. Skipping this match.
# Processing match 7239 of 7268.
# Processing match 7240 of 7268.
# Error processing match 7240: Not a ranked game. Skipping this match.
# Processing match 7241 of 7268.
# Error processing match 7241: Not a ranked game. Skipping this match.
# Processing match 7242 of 7268.
# Processing match 7243 of 7268.
# Error processing match 7243: Not a ranked game. Skipping this match.
# Processing match 7244 of 7268.
# Processing match 7245 of 7268.
# Processing match 7246 of 7268.
# Processing match 7247 of 7268.
# Error processing match 7247: Not a ranked game. Skipping this match.
# Processing match 7248 of 7268.
# Processing match 7249 of 7268.
# Processing match 7250 of 7268.
# Error processing match 7250: Not a ranked game. Skipping this match.
# Processing match 7251 of 7268.
# Processing match 7252 of 7268.
# Error processing match 7252: Not a ranked game. Skipping this match.
# Processing match 7253 of 7268.
# Processing match 7254 of 7268.
# Error processing match 7254: Not a ranked game. Skipping this match.
# Processing match 7255 of 7268.
# Processing match 7256 of 7268.
# Processing match 7257 of 7268.
# Processing match 7258 of 7268.
# Error processing match 7258: Not a ranked game. Skipping this match.
# Processing match 7259 of 7268.
# Processing match 7260 of 7268.
# Error processing match 7260: Not a ranked game. Skipping this match.
# Processing match 7261 of 7268.
# Processing match 7262 of 7268.
# Error processing match 7262: Not a ranked game. Skipping this match.
# Processing match 7263 of 7268.
# Processing match 7264 of 7268.
# Error processing match 7264: Not a ranked game. Skipping this match.
# Processing match 7265 of 7268.
# Error processing match 7265: Not a ranked game. Skipping this match.
# Processing match 7266 of 7268.
# Processing match 7267 of 7268.
# Processing match 7268 of 7268.
# Error processing match 7268: Not a ranked game. Skipping this match.

# %%
print(f'Shape: {all_matches_df.shape}')
all_matches_df.head(10)
# Out:
# Shape: (47670, 56)
#          Match ID  Game Duration   Game Version     Summoner Name  \
# 0  NA1_5095396461           1404  14.16.612.449            K9 BDE
# 1  NA1_5095396461           1404  14.16.612.449              Hani
# 2  NA1_5095396461           1404  14.16.612.449   bean and peanut
# 3  NA1_5095396461           1404  14.16.612.449   Lucius Artorius
# 4  NA1_5095396461           1404  14.16.612.449  whiteman enjoyer
# 5  NA1_5095396461           1404  14.16.612.449        gemi swift
# 6  NA1_5095396461           1404  14.16.612.449      Giraffe Hugs
# 7  NA1_5095396461           1404  14.16.612.449             Cupic
# 8  NA1_5095396461           1404  14.16.612.449      ThëBeesKnees
# 9  NA1_5095396461           1404  14.16.612.449             Shiku
#
#   Summoner Tag  Champion ID Champion Name  Champion Level  Team     Role  \
# 0          NA1          122        Darius              14   100      TOP
# 1        zzzzz          141          Kayn              14   100   JUNGLE
# 2         rina          893        Aurora              14   100   MIDDLE
# 3          CV1           22          Ashe              14   100   BOTTOM
# 4         2222          147     Seraphine              11   100  UTILITY
# 5          NA1           78         Poppy              13   200      TOP
# 6          NA1          876        Lillia              13   200   JUNGLE
# 7        Senna           99           Lux              13   200   MIDDLE
# 8         0001          202          Jhin              12   200   BOTTOM
# 9          LMB          526          Rell               9   200  UTILITY
#
#    Kills  Deaths  Assists   CS  CS (Jungle)  First Blood  First Tower  \
# 0      4       2        4  146            0         True        False
# 1      5       4        9   14          133        False        False
# 2      2       2       13  183            0        False        False
# 3      8       1        8  200            4        False        False
# 4      2       3       13   25            0        False         True
# 5      5       4        1  146            0        False        False
# 6      3       5        5    9          125        False        False
# 7      1       5        1  188            0        False        False
# 8      2       4        6  163            0        False        False
# 9      1       3        8   24            0        False        False
#
#    Objective Stolen  Total Gold Earned  Gold Spent  Gold/Minute  Damage Dealt  \
# 0                 0               9688        8608   413.808623          8867
# 1                 0              10510        9050   448.913791         12101
# 2                 0               9382        7950   400.702712         20446
# 3                 0              12423       11200   530.618963         16308
# 4                 0               7418        6150   316.823169          7943
# 5                 0               8791        8000   375.489477         11528
# 6                 0               8660        8600   369.896944         11602
# 7                 0               7768        7250   331.782796         12022
# 8                 0               7898        7175   337.335038         10315
# 9                 0               5788        5300   247.205844          3754
#
#    % of Team's Damage  Damage Taken  Damage Mitigated  Heal and Shielding  \
# 0            0.135032         14725             11145            0.000000
# 1            0.184288         29216             19095            0.000000
# 2            0.311367         16188              7265            0.000000
# 3            0.248344          7652              3517            0.000000
# 4            0.120969         11305              5905         6384.027344
# 5            0.234211         19294             23368            0.000000
# 6            0.235707         31443             14583            0.000000
# 7            0.244247          9643              5812          902.400024
# 8            0.209562         12305              6903            0.000000
# 9            0.076274         17922             12144            0.000000
#
#    CC Time Dealt  Turret Plates Taken  Turret Takedowns  Vision Score  Rune 1  \
# 0             41                    5                 2            22    8010
# 1            362                    0                 1            14    8010
# 2            214                    2                 1            19    8112
# 3            616                    6                 4            19    8005
# 4            132                    5                 4            51    8465
# 5            782                    1                 1            13    8230
# 6            437                    0                 0            27    8010
# 7            387                    1                 0            10    8128
# 8            153                    0                 1            10    8021
# 9             53                    0                 1            67    8439
#
#    Rune 2  Rune 3  Rune 4  Sec Rune 1  Sec Rune 2  Stat 1  Stat 2  Stat 3  \
# 0    9111    9104    8299        8473        8242    5005    5008    5001
# 1    9111    9105    8017        8138        8105    5008    5008    5001
# 2    8139    8138    8106        8226        8210    5005    5008    5001
# 3    9101    9104    8017        8345        8410    5005    5008    5011
# 4    8463    8473    8453        8009        8017    5005    5010    5011
# 5    8226    8234    8237        8444        8451    5008    5008    5011
# 6    9111    9105    8014        8347        8304    5008    5008    5001
# 7    8126    8138    8106        8017        8009    5008    5008    5011
# 8    8009    9103    8014        8234        8236    5008    5008    5001
# 9    8446    8444    8451        8347        8306    5007    5010    5011
#
#    Summ 1  Summ 2  Item 1  Item 2  Item 3  Item 4  Item 5  Item 6  \
# 0       4       6    1055    3078       0    3053    3111       0
# 1       4      11    6694    6692    3134    3111    1036       0
# 2       4      12    1056    6653    1082    3118    3111       0
# 3       4       1    1055    6672    3046    3031    1036    3006
# 4       4       7    6620    3158    6617    3869    1004       0
# 5       4      12    1054    3111    6660    6662    8020    1029
# 6       4      11    4633    1082    6653    3158    3916       0
# 7       4      14    6655    3020    1082    1056    3145    1058
# 8      21       4    1055    3087    3009    1018    1037    1038
# 9      14       4    1001    3083    3067    3869       0       0
#
#    Triplekills  Quadrakills  Pentakills  Grubs Taken (Team)  \
# 0            0            0           0                   2
# 1            0            0           0                   2
# 2            0            0           0                   2
# 3            0            0           0                   2
# 4            0            0           0                   2
# 5            0            0           0                   4
# 6            0            0           0                   4
# 7            0            0           0                   4
# 8            0            0           0                   4
# 9            0            0           0                   4
#
#    Heralds Taken (Team)  Barons Taken (Team)  Dragons Taken (Team)  \
# 0                     1                    1                     3
# 1                     1                    1                     3
# 2                     1                    1                     3
# 3                     1                    1                     3
# 4                     1                    1                     3
# 5                     0                    0                     0
# 6                     0                    0                     0
# 7                     0                    0                     0
# 8                     0                    0                     0
# 9                     0                    0                     0
#
#    Game Ended in Surrender    Win
# 0                     True   True
# 1                     True   True
# 2                     True   True
# 3                     True   True
# 4                     True   True
# 5                     True  False
# 6                     True  False
# 7                     True  False
# 8                     True  False
# 9                     True  False

# %%
os.makedirs('data', exist_ok=True)

all_matches_df.to_csv(os.path.join('data', 'matches_data.csv'), index=False)

# %%
# Read the DataFrame out of the .csv file in case no longer in memory
all_matches_df = pd.read_csv(os.path.join('data', 'matches_data.csv'))
